# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/set_project_2/data/HimachalPradesh.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L00000HP1994PLC014770
# 1              L15520HP1934PLC000135
# 2              L15543HP1991PLC019065
# 3              L17111HP1982PLC016465
# 4              L17115HP1980PLC005647
# ...                              ...
# 7277           U99999HP1996PLC017761
# 7278           U99999HP1996PTC017558
# 7279           U99999HP1997PLC020122
# 7280           U99999HP1997PLC020203
# 7281           U99999HP1997PTC019692
#
#                                           Company_Name Company_status  \
# 0                           HITKARI INDUSTRIES LIMITED         Active
# 1                                 MOHAN MEAKIN LIMITED         Active
# 2                  MOUNT EVEREST MINERAL WATER LIMITED    Amalgamated
# 3                                  DEEPAK SPINNERS LTD         Active
# 4                   WINSOME TEXTILE INDUSTRIES LIMITED         Active
# ...                                                ...            ...
# 7277  DARLAGHAT GREENFIELD AND ALLIED SERVICES LIMITED     Strike Off
# 7278              PRISTINE PETAL FLORA PRIVATE LIMITED         Active
# 7279                               A V COTSPIN LIMITED     Strike Off
# 7280                    RUBYMINE CHITS COMPANY LIMITED     Strike Off
# 7281                    TRISHMA RESORT PRIVATE LIMITED         Active
#
#      Company_class           Company_Category Company_sub_category  \
# 0           Public  Company limited by Shares     Non-govt company
# 1           Public  Company limited by Shares     Non-govt company
# 2           Public  Company limited by Shares     Non-govt company
# 3           Public  Company limited by Shares     Non-govt company
# 4           Public  Company limited by Shares     Non-govt company
# ...            ...                        ...                  ...
# 7277        Public  Company limited by Shares     Non-govt company
# 7278       Private  Company limited by Shares     Non-govt company
# 7279        Public  Company limited by Shares     Non-govt company
# 7280        Public  Company limited by Shares     Non-govt company
# 7281       Private  Company limited by Shares     Non-govt company
#
#      DATE_OF_REGISTRATION  REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0                29-06-94  Himachal Pradesh        60000000        32054700
# 1                02-11-34  Himachal Pradesh       100000000        42542395
# 2                20-12-91  Himachal Pradesh       350000000       339959710
# 3                25-03-82  Himachal Pradesh       140000000        71893680
# 4                18-09-80  Himachal Pradesh       250000000       198200000
# ...                   ...               ...             ...             ...
# 7277             22-02-96  Himachal Pradesh          500000           10000
# 7278             10-01-96  Himachal Pradesh          100000           10000
# 7279             24-06-97  Himachal Pradesh        10000000             700
# 7280             08-07-97  Himachal Pradesh          100000            3500
# 7281             02-04-97  Himachal Pradesh         2000000         1708000
#
#       Industrial_Class      PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                    0                                Unclassified
# 1                15520  Manufacture of food products and beverages
# 2                15543  Manufacture of food products and beverages
# 3                17111                     Manufacture of textiles
# 4                17115                     Manufacture of textiles
# ...                ...                                         ...
# 7277             99999   Extraterritorial organizations and bodies
# 7278             99999   Extraterritorial organizations and bodies
# 7279             99999   Extraterritorial organizations and bodies
# 7280             99999   Extraterritorial organizations and bodies
# 7281             99999   Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     PLOT NO 18 SECTOR 1INDUSTRIAL AREA PARWANOO SO...
# 1     Solan Brewery, P.O. Solan SOLAN. Solan Brewery...
# 2     Village Dhaula Kuan DISTT SIRMOUR HIMACHAL PRA...
# 3     #121 INDUSTRIAL AREA,BADDI TEH NALAGARH DISTT ...
# 4     1 INDUSTRIAL AREABADDI SOLAN HIMACHAL PRADESH ...
# ...                                                 ...
# 7277  VILL. SULI, P.O. DARLAGHATTEH ARKI DISTT SOLAN...
# 7278  DHOLADAR COLONYNAGROTA BAGWAN DISTT KANGRA H P...
# 7279  52 SECTOR 1PARWANOO SOLAN H P , Unclassified H...
# 7280  # 36MALL ROAD SHIMLA H P , Unclassified HP 000000
# 7281  NANGAL UNA ROADV P O BEHDALA UNA HIMACHAL PRAD...
#
#      REGISTRAR_OF_COMPANIES                                  EMAIL_ADDR  \
# 0      RoC-Himachal Pradesh                      sachdevakk@hotmail.com
# 1      RoC-Himachal Pradesh                       solan@mohanmeakin.com
# 2      RoC-Himachal Pradesh  deepika.srivastava@tataglobalbeverages.com
# 3      RoC-Himachal Pradesh                   puneeta.arora@dslindia.in
# 4      RoC-Himachal Pradesh                   cswtil@winsometextile.com
# ...                     ...                                         ...
# 7277   RoC-Himachal Pradesh                                         NaN
# 7278   RoC-Himachal Pradesh                                         NaN
# 7279   RoC-Himachal Pradesh            globepublications@rediffmail.com
# 7280   RoC-Himachal Pradesh                                         NaN
# 7281   RoC-Himachal Pradesh                     trishmaresort@gmail.com
#
#      Latest_Year_AR Latest_Year_BS
# 0          31-03-20       31-03-20
# 1          31-03-20       31-03-20
# 2          31-03-14       31-03-14
# 3          31-03-20       31-03-20
# 4          31-03-20       31-03-20
# ...             ...            ...
# 7277            NaN            NaN
# 7278            NaN            NaN
# 7279            NaN            NaN
# 7280            NaN            NaN
# 7281       31-03-20       31-03-20
#
# [7282 rows x 17 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER              0
# Company_Name                                 0
# Company_status                               0
# Company_class                                0
# Company_Category                             0
# Company_sub_category                         0
# DATE_OF_REGISTRATION                         0
# REGISTERED_STATE                             0
# AUTHORIZED_CAP                               0
# PAIDUP_CAPITAL                               0
# Industrial_Class                             0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN       0
# Registered_Office_Address                    0
# REGISTRAR_OF_COMPANIES                       0
# EMAIL_ADDR                                1431
# Latest_Year_AR                            3703
# Latest_Year_BS                            3707
# Registration_Year                            0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L00000HP1994PLC014770
# 1              L15520HP1934PLC000135
# 2              L15543HP1991PLC019065
# 3              L17111HP1982PLC016465
# 4              L17115HP1980PLC005647
# ...                              ...
# 7277           U99999HP1996PLC017761
# 7278           U99999HP1996PTC017558
# 7279           U99999HP1997PLC020122
# 7280           U99999HP1997PLC020203
# 7281           U99999HP1997PTC019692
#
#                                           Company_Name Company_status  \
# 0                           HITKARI INDUSTRIES LIMITED         Active
# 1                                 MOHAN MEAKIN LIMITED         Active
# 2                  MOUNT EVEREST MINERAL WATER LIMITED    Amalgamated
# 3                                  DEEPAK SPINNERS LTD         Active
# 4                   WINSOME TEXTILE INDUSTRIES LIMITED         Active
# ...                                                ...            ...
# 7277  DARLAGHAT GREENFIELD AND ALLIED SERVICES LIMITED     Strike Off
# 7278              PRISTINE PETAL FLORA PRIVATE LIMITED         Active
# 7279                               A V COTSPIN LIMITED     Strike Off
# 7280                    RUBYMINE CHITS COMPANY LIMITED     Strike Off
# 7281                    TRISHMA RESORT PRIVATE LIMITED         Active
#
#      Company_class           Company_Category Company_sub_category  \
# 0           Public  Company limited by Shares     Non-govt company
# 1           Public  Company limited by Shares     Non-govt company
# 2           Public  Company limited by Shares     Non-govt company
# 3           Public  Company limited by Shares     Non-govt company
# 4           Public  Company limited by Shares     Non-govt company
# ...            ...                        ...                  ...
# 7277        Public  Company limited by Shares     Non-govt company
# 7278       Private  Company limited by Shares     Non-govt company
# 7279        Public  Company limited by Shares     Non-govt company
# 7280        Public  Company limited by Shares     Non-govt company
# 7281       Private  Company limited by Shares     Non-govt company
#
#       REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  Industrial_Class  \
# 0     Himachal Pradesh        60000000        32054700                 0
# 1     Himachal Pradesh       100000000        42542395             15520
# 2     Himachal Pradesh       350000000       339959710             15543
# 3     Himachal Pradesh       140000000        71893680             17111
# 4     Himachal Pradesh       250000000       198200000             17115
# ...                ...             ...             ...               ...
# 7277  Himachal Pradesh          500000           10000             99999
# 7278  Himachal Pradesh          100000           10000             99999
# 7279  Himachal Pradesh        10000000             700             99999
# 7280  Himachal Pradesh          100000            3500             99999
# 7281  Himachal Pradesh         2000000         1708000             99999
#
#           PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                                   Unclassified
# 1     Manufacture of food products and beverages
# 2     Manufacture of food products and beverages
# 3                        Manufacture of textiles
# 4                        Manufacture of textiles
# ...                                          ...
# 7277   Extraterritorial organizations and bodies
# 7278   Extraterritorial organizations and bodies
# 7279   Extraterritorial organizations and bodies
# 7280   Extraterritorial organizations and bodies
# 7281   Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     PLOT NO 18 SECTOR 1INDUSTRIAL AREA PARWANOO SO...
# 1     Solan Brewery, P.O. Solan SOLAN. Solan Brewery...
# 2     Village Dhaula Kuan DISTT SIRMOUR HIMACHAL PRA...
# 3     #121 INDUSTRIAL AREA,BADDI TEH NALAGARH DISTT ...
# 4     1 INDUSTRIAL AREABADDI SOLAN HIMACHAL PRADESH ...
# ...                                                 ...
# 7277  VILL. SULI, P.O. DARLAGHATTEH ARKI DISTT SOLAN...
# 7278  DHOLADAR COLONYNAGROTA BAGWAN DISTT KANGRA H P...
# 7279  52 SECTOR 1PARWANOO SOLAN H P , Unclassified H...
# 7280  # 36MALL ROAD SHIMLA H P , Unclassified HP 000000
# 7281  NANGAL UNA ROADV P O BEHDALA UNA HIMACHAL PRAD...
#
#      REGISTRAR_OF_COMPANIES Latest_Year_AR Latest_Year_BS  Registration_Year
# 0      RoC-Himachal Pradesh       31-03-20       31-03-20               1994
# 1      RoC-Himachal Pradesh       31-03-20       31-03-20               2034
# 2      RoC-Himachal Pradesh       31-03-14       31-03-14               1991
# 3      RoC-Himachal Pradesh       31-03-20       31-03-20               1982
# 4      RoC-Himachal Pradesh       31-03-20       31-03-20               1980
# ...                     ...            ...            ...                ...
# 7277   RoC-Himachal Pradesh            NaN            NaN               1996
# 7278   RoC-Himachal Pradesh            NaN            NaN               1996
# 7279   RoC-Himachal Pradesh            NaN            NaN               1997
# 7280   RoC-Himachal Pradesh            NaN            NaN               1997
# 7281   RoC-Himachal Pradesh       31-03-20       31-03-20               1997
#
# [7282 rows x 16 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='Company_status', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Industrial_Class', data=df[(df['Registration_Year'] <= 2020) & (df['Registration_Year'] >= 1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'Company_Category' column
print(df['Company_Category'].unique())
# Out:
# ['Company limited by Shares' 'Unlimited Company'
#  'Company Limited by Guarantee']

# %%
import numpy as np
df['Company_Category'] =df['Company_Category'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Company_Category', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Other business activities                                                         680
# Construction                                                                      310
# Computer and related activities                                                   252
# Wholesale trade and commission trade, except of motor vehicles and motorcycles    150
# Other community, social and personal service activities                           149
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# # Model

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame
# Convert 'Latest_Year_AR' to datetime format
df['Latest_Year_AR'] = pd.to_datetime(df['Latest_Year_AR'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = [
    'Other business activities',
    'Construction',
    'Computer and related activities',
    'Wholesale trade and commission trade, except of motor vehicles and motorcycles',
    'Other community, social and personal service activities'
]

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index, y.values, marker='o', label='Historical Data')
    forecast_years = pd.date_range(start=y.index.max() + pd.DateOffset(1), periods=forecast_steps, freq='Y')
    plt.plot(forecast_years, forecast_values.values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Other business activities for 2021-2025:
# 2021-01-01    61.565930
# 2022-01-01    68.508134
# 2023-01-01    72.343440
# 2024-01-01    74.462303
# 2025-01-01    75.632895
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Construction for 2021-2025:
# 2021-01-01    40.166451
# 2022-01-01    39.713266
# 2023-01-01    39.601255
# 2024-01-01    39.573571
# 2025-01-01    39.566728
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Computer and related activities for 2021-2025:
# 2021-01-01    48.938124
# 2022-01-01    45.257135
# 2023-01-01    48.697778
# 2024-01-01    45.481788
# 2025-01-01    48.487794
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Wholesale trade and commission trade, except of motor vehicles and motorcycles for 2021-2025:
# 2021-01-01    44.021921
# 2022-01-01    48.832095
# 2023-01-01    53.439449
# 2024-01-01    57.852537
# 2025-01-01    62.079549
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Other community, social and personal service activities for 2021-2025:
# 2021-01-01    23.813332
# 2022-01-01    23.815561
# 2023-01-01    23.815534
# 2024-01-01    23.815535
# 2025-01-01    23.815535
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
