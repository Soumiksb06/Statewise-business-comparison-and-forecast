# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data\Meghalaya.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L26942ML2001PLC006663
# 1              L27310ML2011PLC008564
# 2              L27310ML2011PLC008578
# 3              L51909ML1993PLC003931
# 4              L55101ML1985PLC002457
# ...                              ...
# 1161           U99999ML1966PLC013566
# 1162           U99999ML1966PLC013567
# 1163           U99999ML1966PLC013570
# 1164           U99999ML1966PLC013573
# 1165           U99999ML1997PLC013474
#
#                                       Company_Name             Company_status  \
# 0                              STAR CEMENT LIMITED                     Active
# 1                    STAR FERRO AND CEMENT LIMITED                Amalgamated
# 2                    SHYAM CENTURY FERROUS LIMITED                     Active
# 3     EASTERN MINING AND ALLIED INDUSTRIESLIMITED.                     Active
# 4                       INDRAPRASTHA HOLDINGS LTD.                 Strike Off
# ...                                            ...                        ...
# 1161     KOKAN CANNED FOOD PRODUCTS PRIVATELIMITED  Not Available for eFiling
# 1162  SHREE SADGURU BENEFIT COMPANY PRIVATELIMITED  Not Available for eFiling
# 1163             BHARAT VITRIFIERS PRIVATE LIMITED  Not Available for eFiling
# 1164        CONSOLIDATED ANODIGERS PRIVATE LIMITED  Not Available for eFiling
# 1165                                          NENS  Not Available for eFiling
#
#      Company_class              Company_Category Company_sub_category  \
# 0           Public     Company limited by Shares     Non-govt company
# 1           Public     Company limited by Shares     Non-govt company
# 2           Public     Company limited by Shares     Non-govt company
# 3           Public     Company limited by Shares     Non-govt company
# 4           Public     Company limited by Shares     Non-govt company
# ...            ...                           ...                  ...
# 1161        Public  Company Limited by Guarantee     Non-govt company
# 1162        Public  Company Limited by Guarantee     Non-govt company
# 1163        Public  Company Limited by Guarantee     Non-govt company
# 1164        Public  Company Limited by Guarantee     Non-govt company
# 1165        Public  Company Limited by Guarantee     Non-govt company
#
#      DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0                02-11-01        Meghalaya       830000000       412429000
# 1                10-03-11        Meghalaya       230000000       222172990
# 2                12-04-11        Meghalaya       222700000       222172990
# 3                15-06-93        Meghalaya       250000000       244502000
# 4                29-11-85        Meghalaya        20000000        19001900
# ...                   ...              ...             ...             ...
# 1161             02-09-66        Meghalaya               0               0
# 1162             02-09-66        Meghalaya               0               0
# 1163             07-09-66        Meghalaya               0               0
# 1164             16-09-66        Meghalaya               0               0
# 1165             09-07-97        Meghalaya               0               0
#
#       Industrial_Class             PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                26942  Manufacture of other non-metallic mineral prod...
# 1                27310                        Manufacture of basic metals
# 2                27310                        Manufacture of basic metals
# 3                51909  Wholesale trade and commission trade, except o...
# 4                55101                             Hotels and restaurants
# ...                ...                                                ...
# 1161             99999          Extraterritorial organizations and bodies
# 1162             99999          Extraterritorial organizations and bodies
# 1163             99999          Extraterritorial organizations and bodies
# 1164             99999          Extraterritorial organizations and bodies
# 1165             99999          Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     VILL LUMSHNONG,KHALIEHRIAT JAINTIA HILLS MEGHA...
# 1     Vill.: Lumshnong, PO: Khaliehriat Lumshnong , ...
# 2     Vill.: Lumshnong, PO: Khaliehriat Lumshnong , ...
# 3     "AGYA COTTAGE" LOWER LACHUMIERE SHILLONG , Eas...
# 4     AUCKLAND ROAD, OPP. P&T QUARTER DIST. EAST KHA...
# ...                                                 ...
# 1161                                  , Unclassified ML
# 1162                                  , Unclassified ML
# 1163                                  , Unclassified ML
# 1164                                  , Unclassified ML
# 1165                                  , Unclassified ML
#
#      REGISTRAR_OF_COMPANIES                          EMAIL_ADDR  \
# 0              RoC-Shillong  debabratathakurta@starcement.co.in
# 1              RoC-Shillong  debabratathakurta@starcement.co.in
# 2              RoC-Shillong        nehaagarwal@starcement.co.in
# 3              RoC-Shillong                                 NaN
# 4              RoC-Shillong                                 NaN
# ...                     ...                                 ...
# 1161           RoC-Shillong                                 NaN
# 1162           RoC-Shillong                                 NaN
# 1163           RoC-Shillong                                 NaN
# 1164           RoC-Shillong                                 NaN
# 1165           RoC-Shillong                                 NaN
#
#      Latest_Year_AR Latest_Year_BS
# 0          31-03-20       31-03-20
# 1          31-03-16       31-03-16
# 2          31-03-20       31-03-20
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 1161            NaN            NaN
# 1162            NaN            NaN
# 1163            NaN            NaN
# 1164            NaN            NaN
# 1165            NaN            NaN
#
# [1166 rows x 17 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER             0
# Company_Name                                0
# Company_status                              0
# Company_class                               0
# Company_Category                            0
# Company_sub_category                        0
# DATE_OF_REGISTRATION                        0
# REGISTERED_STATE                            0
# AUTHORIZED_CAP                              0
# PAIDUP_CAPITAL                              0
# Industrial_Class                            0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN      0
# Registered_Office_Address                   0
# REGISTRAR_OF_COMPANIES                      0
# EMAIL_ADDR                                311
# Latest_Year_AR                            514
# Latest_Year_BS                            516
# Registration_Year                           0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L26942ML2001PLC006663
# 1              L27310ML2011PLC008564
# 2              L27310ML2011PLC008578
# 3              L51909ML1993PLC003931
# 4              L55101ML1985PLC002457
# ...                              ...
# 1161           U99999ML1966PLC013566
# 1162           U99999ML1966PLC013567
# 1163           U99999ML1966PLC013570
# 1164           U99999ML1966PLC013573
# 1165           U99999ML1997PLC013474
#
#                                       Company_Name             Company_status  \
# 0                              STAR CEMENT LIMITED                     Active
# 1                    STAR FERRO AND CEMENT LIMITED                Amalgamated
# 2                    SHYAM CENTURY FERROUS LIMITED                     Active
# 3     EASTERN MINING AND ALLIED INDUSTRIESLIMITED.                     Active
# 4                       INDRAPRASTHA HOLDINGS LTD.                 Strike Off
# ...                                            ...                        ...
# 1161     KOKAN CANNED FOOD PRODUCTS PRIVATELIMITED  Not Available for eFiling
# 1162  SHREE SADGURU BENEFIT COMPANY PRIVATELIMITED  Not Available for eFiling
# 1163             BHARAT VITRIFIERS PRIVATE LIMITED  Not Available for eFiling
# 1164        CONSOLIDATED ANODIGERS PRIVATE LIMITED  Not Available for eFiling
# 1165                                          NENS  Not Available for eFiling
#
#      Company_class              Company_Category Company_sub_category  \
# 0           Public     Company limited by Shares     Non-govt company
# 1           Public     Company limited by Shares     Non-govt company
# 2           Public     Company limited by Shares     Non-govt company
# 3           Public     Company limited by Shares     Non-govt company
# 4           Public     Company limited by Shares     Non-govt company
# ...            ...                           ...                  ...
# 1161        Public  Company Limited by Guarantee     Non-govt company
# 1162        Public  Company Limited by Guarantee     Non-govt company
# 1163        Public  Company Limited by Guarantee     Non-govt company
# 1164        Public  Company Limited by Guarantee     Non-govt company
# 1165        Public  Company Limited by Guarantee     Non-govt company
#
#      REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  Industrial_Class  \
# 0           Meghalaya       830000000       412429000             26942
# 1           Meghalaya       230000000       222172990             27310
# 2           Meghalaya       222700000       222172990             27310
# 3           Meghalaya       250000000       244502000             51909
# 4           Meghalaya        20000000        19001900             55101
# ...               ...             ...             ...               ...
# 1161        Meghalaya               0               0             99999
# 1162        Meghalaya               0               0             99999
# 1163        Meghalaya               0               0             99999
# 1164        Meghalaya               0               0             99999
# 1165        Meghalaya               0               0             99999
#
#                  PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0     Manufacture of other non-metallic mineral prod...
# 1                           Manufacture of basic metals
# 2                           Manufacture of basic metals
# 3     Wholesale trade and commission trade, except o...
# 4                                Hotels and restaurants
# ...                                                 ...
# 1161          Extraterritorial organizations and bodies
# 1162          Extraterritorial organizations and bodies
# 1163          Extraterritorial organizations and bodies
# 1164          Extraterritorial organizations and bodies
# 1165          Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     VILL LUMSHNONG,KHALIEHRIAT JAINTIA HILLS MEGHA...
# 1     Vill.: Lumshnong, PO: Khaliehriat Lumshnong , ...
# 2     Vill.: Lumshnong, PO: Khaliehriat Lumshnong , ...
# 3     "AGYA COTTAGE" LOWER LACHUMIERE SHILLONG , Eas...
# 4     AUCKLAND ROAD, OPP. P&T QUARTER DIST. EAST KHA...
# ...                                                 ...
# 1161                                  , Unclassified ML
# 1162                                  , Unclassified ML
# 1163                                  , Unclassified ML
# 1164                                  , Unclassified ML
# 1165                                  , Unclassified ML
#
#      REGISTRAR_OF_COMPANIES Latest_Year_AR Latest_Year_BS  Registration_Year
# 0              RoC-Shillong       31-03-20       31-03-20               2001
# 1              RoC-Shillong       31-03-16       31-03-16               2011
# 2              RoC-Shillong       31-03-20       31-03-20               2011
# 3              RoC-Shillong            NaN            NaN               1993
# 4              RoC-Shillong            NaN            NaN               1985
# ...                     ...            ...            ...                ...
# 1161           RoC-Shillong            NaN            NaN               2066
# 1162           RoC-Shillong            NaN            NaN               2066
# 1163           RoC-Shillong            NaN            NaN               2066
# 1164           RoC-Shillong            NaN            NaN               2066
# 1165           RoC-Shillong            NaN            NaN               1997
#
# [1166 rows x 16 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='Company_status', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Industrial_Class', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'Company_Category' column
print(df['Company_Category'].unique())
# Out:
# ['Company limited by Shares' 'Company Limited by Guarantee']

# %%
import numpy as np
df['Company_Category'] =df['Company_Category'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Company_Category', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Other business activities                              33
# Agriculture, hunting and related service activities    23
# Computer and related activities                        20
# Other mining and quarrying                             12
# Hotels and restaurants                                 11
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# ## Authorized capital

# %%
df.loc[:, 'AUTHORIZED_CAP'] = df['AUTHORIZED_CAP'].astype(float)
df.loc[:, 'PAIDUP_CAPITAL'] = df['PAIDUP_CAPITAL'].astype(float)
# Group by 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN' and calculate the mean of 'AUTHORIZED_CAP' and 'PAIDUP_CAPITAL'
grouped_df = df.groupby('PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN')[['AUTHORIZED_CAP', 'PAIDUP_CAPITAL']].mean().reset_index()
df = df.sort_values(by='Registration_Year')

# Calculate the percentage change in authorized capital for each activity over time
df['CAPITAL_CHANGE'] = df.groupby(['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', 'Registration_Year'])['AUTHORIZED_CAP'].pct_change().fillna(0)

# Group by 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN' and calculate the mean of 'CAPITAL_CHANGE'
activity_trend_df = df.groupby(['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN','Registration_Year'])['CAPITAL_CHANGE'].mean().reset_index()

# Print the new DataFrame with the trend analysis
activity_trend_df2= activity_trend_df.interpolate()
activity_trend_df2
# Out:
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\3552500774.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'AUTHORIZED_CAP'] = df['AUTHORIZED_CAP'].astype(float)
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\3552500774.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'PAIDUP_CAPITAL'] = df['PAIDUP_CAPITAL'].astype(float)
#                 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  Registration_Year  \
# 0    Agriculture, hunting and related service activ...               1974
# 1    Agriculture, hunting and related service activ...               1989
# 2    Agriculture, hunting and related service activ...               1991
# 3    Agriculture, hunting and related service activ...               1994
# 4    Agriculture, hunting and related service activ...               1995
# ..                                                 ...                ...
# 571  Wholesale trade and commission trade, except o...               2020
# 572  Wholesale trade and commission trade, except o...               2021
# 573  Wholesale trade and commission trade, except o...               2050
# 574  Wholesale trade and commission trade, except o...               2072
# 575  Wholesale trade and commission trade, except o...               2073
#
#      CAPITAL_CHANGE
# 0          0.000000
# 1          1.666667
# 2          0.000000
# 3          0.000000
# 4          0.033333
# ..              ...
# 571        4.444444
# 572        0.000000
# 573        0.000000
# 574        0.000000
# 575        0.000000
#
# [576 rows x 3 columns]

# %% [markdown]
# ## Comparison Score

# %%
# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=['Activity_1', 'Activity_2', 'Comparison'])

# Comparative Analysis: This compares the mean paid-up capital of all business activities.
# It helps in understanding their relative performance and market standing.
for i in range(len(grouped_df) - 1):
    for j in range(i + 1, len(grouped_df)):
        activity1_capital = grouped_df.loc[i, 'PAIDUP_CAPITAL']
        activity2_capital = grouped_df.loc[j, 'PAIDUP_CAPITAL']
        comparison = activity1_capital / activity2_capital
        new_row = pd.DataFrame({'Activity_1': [grouped_df.loc[i, 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN']],
                                'Activity_2': [grouped_df.loc[j, 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN']],
                                'Comparison': [comparison]})
        results_df = pd.concat([results_df, new_row], ignore_index=True)

# Print the results DataFrame
results_df
# Out:
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_12516\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
#                                             Activity_1  \
# 0    Agriculture, hunting and related service activ...
# 1    Agriculture, hunting and related service activ...
# 2    Agriculture, hunting and related service activ...
# 3    Agriculture, hunting and related service activ...
# 4    Agriculture, hunting and related service activ...
# ..                                                 ...
# 985  Tanning and dressing of leather; manufacture o...
# 986  Tanning and dressing of leather; manufacture o...
# 987              Transport, storage and communications
# 988              Transport, storage and communications
# 989  Wholesale and retail trade ; repair of motor v...
#
#                                             Activity_2  Comparison
# 0                      Computer and related activities   20.882264
# 1                                         Construction    0.733111
# 2                                            Education    5.388301
# 3         Electricity, gas, steam and hot water supply    0.002914
# 4    Extraction of crude petroleum and natural gas;...   47.655176
# ..                                                 ...         ...
# 985  Wholesale and retail trade ; repair of motor v...    0.124661
# 986  Wholesale trade and commission trade, except o...    0.013916
# 987  Wholesale and retail trade ; repair of motor v...   13.355307
# 988  Wholesale trade and commission trade, except o...    1.490846
# 989  Wholesale trade and commission trade, except o...    0.111629
#
# [990 rows x 3 columns]

# %% [markdown]
# ## Liquidity Ratios

# %%
df = df.copy()

# Calculate the liquidity ratio without warnings
df.loc[:, 'LIQUIDITY_RATIO'] = df['AUTHORIZED_CAP'] / df['PAIDUP_CAPITAL']

# Now, let's create a smaller DataFrame to showcase the liquidity ratios
# Selecting relevant columns for the smaller DataFrame
liquidity_df = df[['Company_Name', 'AUTHORIZED_CAP', 'PAIDUP_CAPITAL', 'LIQUIDITY_RATIO']].copy()

# Displaying the smaller DataFrame
print("Smaller DataFrame showcasing Liquidity Ratios:")
liquidity_df
# Out:
# Smaller DataFrame showcasing Liquidity Ratios:
#                                    Company_Name  AUTHORIZED_CAP  \
# 26            MEGHALAYA PHYTOCHEMICALS LIMITED.      10000000.0
# 559                   DEVELOPMENT INVESTORS LTD      10000000.0
# 579         GITA CREDIT & INVESTMENT CO PVT LTD         30000.0
# 685                           M.M.MOTOR PVT LTD        500000.0
# 249            MEGHALAYA SPINNING MILLS PVT LTD        200000.0
# ..                                          ...             ...
# 913    MEGHALAYA CREDIT & INVESTMENT CO PVT LTD         25000.0
# 733  SPLENDID FINANCE AND HIRE PURCHASE PVT LTD         25000.0
# 278                  MEGHALAYA PLYWOODS LIMITED       2500000.0
# 252     MEGHALAYA JUTE MANUFACTURING CO PVT LTD       1000000.0
# 238                ASSOCIATED BEVERAGES PVT LTD      10000000.0
#
#      PAIDUP_CAPITAL  LIQUIDITY_RATIO
# 26        9000000.0         1.111111
# 559       2244700.0         4.454938
# 579          2200.0        13.636364
# 685        148000.0         3.378378
# 249         83000.0         2.409639
# ..              ...              ...
# 913          1000.0        25.000000
# 733          5000.0         5.000000
# 278       2349880.0         1.063884
# 252        900000.0         1.111111
# 238        820000.0        12.195122
#
# [1166 rows x 4 columns]

# %% [markdown]
# # Model

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame
# Convert 'Latest_Year_AR' to datetime format
df['Latest_Year_AR'] = pd.to_datetime(df['Latest_Year_AR'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = [
    'Other business activities',
    'Agriculture, hunting and related service activities',
    'Computer and related activities',
    'Other mining and quarrying',
    'Hotels and restaurants'
]

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index.year, y.values, marker='o', label='Historical Data')
    plt.plot(range(y.index.year.max() + 1, y.index.year.max() + 1 + forecast_steps), forecast_values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xticks(np.arange(2013, 2026, 1))
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Forecasted registrations for Other business activities for 2021-2025:
# 2021-01-01    8.750237
# 2022-01-01    8.784981
# 2023-01-01    8.786590
# 2024-01-01    8.786664
# 2025-01-01    8.786668
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Agriculture, hunting and related service activities for 2021-2025:
# 2021-01-01    2.901272
# 2022-01-01    2.876840
# 2023-01-01    2.877502
# 2024-01-01    2.877484
# 2025-01-01    2.877485
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecasted registrations for Computer and related activities for 2021-2025:
# 7     1.073327
# 8     1.044575
# 9     1.055849
# 10    1.051428
# 11    1.053161
# Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecasted registrations for Other mining and quarrying for 2021-2025:
# 6     0.999998
# 7     0.999998
# 8     0.999998
# 9     0.999998
# 10    0.999998
# Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecasted registrations for Hotels and restaurants for 2021-2025:
# 4    6.000049
# 5    6.000049
# 6    6.000049
# 7    6.000049
# 8    6.000049
# Name: predicted_mean, dtype: float64
