# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/set_project_2/data/Andhra_Pradesh.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#       CORPORATE_IDENTIFICATION_NUMBER  \
# 0                              F01537
# 1                              F01591
# 2                              F01617
# 3                              F01626
# 4                              F01659
# ...                               ...
# 33045           U74999AP2020PTC114027
# 33046           U74999AP2020PTC114030
# 33047           U74999AP2020PTC114040
# 33048           U74999AP2020PTC114048
# 33049           U74999AP2020PTC114066
#
#                                        COMPANY_NAME COMPANY_STATUS  \
# 0                         UNIVERSAL ASIA LIMITED              ACTV
# 1            DILBURY DOGLAS CONSTRUCTION LIMITED              ACTV
# 2             ASSOCIATED TOBACCO COMPANY LIMITED              ACTV
# 3                            WORLD EDUCATION INC              ACTV
# 4              UNIVERSAL LEAF (ASIA) PTE LIMITED              NAEF
# ...                                             ...            ...
# 33045        DUROTECH INDUSTRIES PRIVATE LIMITED              ACTV
# 33046  TUOJIANG TECHNOLOGY SERVICE PRIVATELIMITED             ACTV
# 33047    MOJO OVERSEAS CONSULTANCY PRIVATELIMITED             ACTV
# 33048                PICK A BOOK PRIVATE LIMITED              ACTV
# 33049   HREEM CONSULTANCY CATALYST PRIVATELIMITED             ACTV
#
#       COMPANY_CLASS           COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 0               NaN                        NaN                  NaN
# 1               NaN                        NaN                  NaN
# 2               NaN                        NaN                  NaN
# 3               NaN                        NaN                  NaN
# 4               NaN                        NaN                  NaN
# ...             ...                        ...                  ...
# 33045       Private  Company limited by Shares     Non-govt company
# 33046       Private  Company limited by Shares     Non-govt company
# 33047       Private  Company limited by Shares     Non-govt company
# 33048       Private  Company limited by Shares     Non-govt company
# 33049       Private  Company limited by Shares     Non-govt company
#
#       DATE_OF_REGISTRATION REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0               13-10-1998   Andhra Pradesh             0.0             0.0
# 1                      NaN   Andhra Pradesh             0.0             0.0
# 2                      NaN   Andhra Pradesh             0.0             0.0
# 3               20-08-1999   Andhra Pradesh             0.0             0.0
# 4                      NaN   Andhra Pradesh             0.0             0.0
# ...                    ...              ...             ...             ...
# 33045           28-01-2020   Andhra Pradesh        100000.0        100000.0
# 33046           28-01-2020   Andhra Pradesh       1000000.0        100000.0
# 33047           29-01-2020   Andhra Pradesh       1000000.0        100000.0
# 33048           30-01-2020   Andhra Pradesh        900000.0        100000.0
# 33049           31-01-2020   Andhra Pradesh       1000000.0        100000.0
#
#        INDUSTRIAL_CLASS       PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                   NaN                         Agriculture & allied
# 1                   NaN                         Agriculture & allied
# 2                   NaN                         Agriculture & allied
# 3                   NaN                         Agriculture & allied
# 4                   NaN                         Agriculture & allied
# ...                 ...                                          ...
# 33045           74999.0  Real estate renting and business activities
# 33046           74999.0  Real estate renting and business activities
# 33047           74999.0  Real estate renting and business activities
# 33048           74999.0  Real estate renting and business activities
# 33049           74999.0  Real estate renting and business activities
#
#                                REGISTERED_OFFICE_ADDRESS  \
# 0                4-5-3/1 LALITHANANDA NAGARVIDYA VIHAR
# 1      205 ASHOKA BHOOPAL CHAMBERSSP ROAD SECUNDERABAD
# 2        D NO 1-2-52 1ST LANE 1ST RIGHTCROSS JKC NAGAR
# 3      7-113, FLAT 103, BHAVANA RESIDENCY,MAHDHURAPUR...
# 4      DOOR NO 3 28 244A NALANDANAGAR 3RD LANE RING R...
# ...                                                  ...
# 33045  43-17-11, BL# 87, BLOCK # 87,SINGH NAGAR, AZIT...
# 33046          21, Srinivasa nagar,Revenue Ward No 25,
# 33047  2/46, Near Annamaiah Temple,Thallapaka, Rajamp...
# 33048  Dno.10-50-18/1(22), Flat No.302,Siripuram Towe...
# 33049  D NO. 18-857, BALAJI NAGAR, COOPERATIVESUGAR F...
#
#       REGISTRAR_OF_COMPANIES                          EMAIL_ADDR  \
# 0                  ROC DELHI                                 NaN
# 1                  ROC DELHI                                 NaN
# 2                  ROC DELHI                                 NaN
# 3                  ROC DELHI                 WORLDED@YAHOO.CO.IN
# 4                  ROC DELHI                 rodney@ualindia.com
# ...                      ...                                 ...
# 33045                    NaN  durotechindustriespvtltd@gmail.com
# 33046                    NaN    tuojiangprivatelimited@gmail.com
# 33047                    NaN              sunandasamba@gmail.com
# 33048                    NaN               kvtramesh77@gmail.com
# 33049                    NaN                svaddadi34@gmail.com
#
#       LATEST_YEAR_ANNUAL_RETURN LATEST_YEAR_FINANCIAL_STATEMENT
# 0                           NaN                             NaN
# 1                           NaN                             NaN
# 2                           NaN                             NaN
# 3                           NaN                             NaN
# 4                           NaN                             NaN
# ...                         ...                             ...
# 33045                       NaN                             NaN
# 33046                       NaN                             NaN
# 33047                       NaN                             NaN
# 33048                       NaN                             NaN
# 33049                       NaN                             NaN
#
# [33050 rows x 17 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_6008/348113690.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)
# C:\Users\ritti\AppData\Local\Temp/ipykernel_6008/348113690.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER               0
# COMPANY_NAME                                  0
# COMPANY_STATUS                                0
# COMPANY_CLASS                                62
# COMPANY_CATEGORY                             62
# COMPANY_SUB_CATEGORY                         65
# DATE_OF_REGISTRATION                          0
# REGISTERED_STATE                              0
# AUTHORIZED_CAP                                0
# PAIDUP_CAPITAL                                0
# INDUSTRIAL_CLASS                             61
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN        0
# REGISTERED_OFFICE_ADDRESS                   257
# REGISTRAR_OF_COMPANIES                    32890
# EMAIL_ADDR                                 6802
# LATEST_YEAR_ANNUAL_RETURN                 17593
# LATEST_YEAR_FINANCIAL_STATEMENT           17572
# Registration_Year                             0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#       CORPORATE_IDENTIFICATION_NUMBER  \
# 0                              F01537
# 3                              F01626
# 5                              F01747
# 6                              F01765
# 7                              F01901
# ...                               ...
# 33045           U74999AP2020PTC114027
# 33046           U74999AP2020PTC114030
# 33047           U74999AP2020PTC114040
# 33048           U74999AP2020PTC114048
# 33049           U74999AP2020PTC114066
#
#                                        COMPANY_NAME COMPANY_STATUS  \
# 0                         UNIVERSAL ASIA LIMITED              ACTV
# 3                            WORLD EDUCATION INC              ACTV
# 5                        TELECRUZ TECHNOLOGY INC              ACTV
# 6                        TYCO HEALTHCARE PTE LTD              ACTV
# 7                        QUANTUM CONSULTANTS INC              ACTV
# ...                                             ...            ...
# 33045        DUROTECH INDUSTRIES PRIVATE LIMITED              ACTV
# 33046  TUOJIANG TECHNOLOGY SERVICE PRIVATELIMITED             ACTV
# 33047    MOJO OVERSEAS CONSULTANCY PRIVATELIMITED             ACTV
# 33048                PICK A BOOK PRIVATE LIMITED              ACTV
# 33049   HREEM CONSULTANCY CATALYST PRIVATELIMITED             ACTV
#
#       COMPANY_CLASS           COMPANY_CATEGORY COMPANY_SUB_CATEGORY  \
# 0               NaN                        NaN                  NaN
# 3               NaN                        NaN                  NaN
# 5               NaN                        NaN                  NaN
# 6               NaN                        NaN                  NaN
# 7               NaN                        NaN                  NaN
# ...             ...                        ...                  ...
# 33045       Private  Company limited by Shares     Non-govt company
# 33046       Private  Company limited by Shares     Non-govt company
# 33047       Private  Company limited by Shares     Non-govt company
# 33048       Private  Company limited by Shares     Non-govt company
# 33049       Private  Company limited by Shares     Non-govt company
#
#       REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  INDUSTRIAL_CLASS  \
# 0       Andhra Pradesh             0.0             0.0               NaN
# 3       Andhra Pradesh             0.0             0.0               NaN
# 5       Andhra Pradesh             0.0             0.0               NaN
# 6       Andhra Pradesh             0.0             0.0               NaN
# 7       Andhra Pradesh             0.0             0.0               NaN
# ...                ...             ...             ...               ...
# 33045   Andhra Pradesh        100000.0        100000.0           74999.0
# 33046   Andhra Pradesh       1000000.0        100000.0           74999.0
# 33047   Andhra Pradesh       1000000.0        100000.0           74999.0
# 33048   Andhra Pradesh        900000.0        100000.0           74999.0
# 33049   Andhra Pradesh       1000000.0        100000.0           74999.0
#
#             PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                             Agriculture & allied
# 3                             Agriculture & allied
# 5                             Agriculture & allied
# 6                             Agriculture & allied
# 7                             Agriculture & allied
# ...                                            ...
# 33045  Real estate renting and business activities
# 33046  Real estate renting and business activities
# 33047  Real estate renting and business activities
# 33048  Real estate renting and business activities
# 33049  Real estate renting and business activities
#
#                                REGISTERED_OFFICE_ADDRESS  \
# 0                4-5-3/1 LALITHANANDA NAGARVIDYA VIHAR
# 3      7-113, FLAT 103, BHAVANA RESIDENCY,MAHDHURAPUR...
# 5          10-1-98 3RD FL HCL TOWER44 DWARKADAS COLONY
# 6                   145 RAJIV NAGARYUSUFGNDA HYDERABAD
# 7                       502-A2 CYBER TOWERSHI-TEC CITY
# ...                                                  ...
# 33045  43-17-11, BL# 87, BLOCK # 87,SINGH NAGAR, AZIT...
# 33046          21, Srinivasa nagar,Revenue Ward No 25,
# 33047  2/46, Near Annamaiah Temple,Thallapaka, Rajamp...
# 33048  Dno.10-50-18/1(22), Flat No.302,Siripuram Towe...
# 33049  D NO. 18-857, BALAJI NAGAR, COOPERATIVESUGAR F...
#
#       REGISTRAR_OF_COMPANIES LATEST_YEAR_ANNUAL_RETURN  \
# 0                  ROC DELHI                       NaN
# 3                  ROC DELHI                       NaN
# 5                  ROC DELHI                       NaN
# 6                  ROC DELHI                       NaN
# 7                  ROC DELHI                       NaN
# ...                      ...                       ...
# 33045                    NaN                       NaN
# 33046                    NaN                       NaN
# 33047                    NaN                       NaN
# 33048                    NaN                       NaN
# 33049                    NaN                       NaN
#
#       LATEST_YEAR_FINANCIAL_STATEMENT  Registration_Year
# 0                                 NaN               1998
# 3                                 NaN               1999
# 5                                 NaN               2001
# 6                                 NaN               2000
# 7                                 NaN               2002
# ...                               ...                ...
# 33045                             NaN               2020
# 33046                             NaN               2020
# 33047                             NaN               2020
# 33048                             NaN               2020
# 33049                             NaN               2020
#
# [32989 rows x 16 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2018) & (df['Registration_Year']>=1989)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='COMPANY_STATUS', data=df[(df['Registration_Year']<=2018) & (df['Registration_Year']>=1989)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# Drop rows where 'INDUSTRIAL_CLASS' is missing
filtered_df = df.dropna(subset=['INDUSTRIAL_CLASS'])

# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='INDUSTRIAL_CLASS', data=filtered_df[(filtered_df['Registration_Year'] <= 2020) & (filtered_df['Registration_Year'] >= 1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'COMPANY_CATEGORY' column
print(df['COMPANY_CATEGORY'].unique())
# Out:
# [nan 'Company limited by Shares' 'Company Limited by Guarantee'
#  'Unlimited Company']

# %%
import numpy as np
df['COMPANY_CATEGORY'] =df['COMPANY_CATEGORY'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='COMPANY_CATEGORY', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Real estate renting and business activities                                                         7129
# Manufacturing                                                                                       2042
# Construction                                                                                        1676
# Agriculture & allied                                                                                1264
# Wholesale and retail trade repair of motor vehicles motorcycles and personal and household goods     982
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# # Model

# %%
# Assuming 'df' is your DataFrame
# Convert 'LATEST_YEAR_ANNUAL_RETURN' to datetime format
df['LATEST_YEAR_ANNUAL_RETURN'] = pd.to_datetime(df['LATEST_YEAR_ANNUAL_RETURN'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = ['Real estate renting and business activities', 'Manufacturing','Construction','Agriculture & allied','Wholesale and retail trade repair of motor vehicles motorcycles and personal and household goods']

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index.year, y.values, marker='o', label='Historical Data')
    plt.plot(range(y.index.year.max() + 1, y.index.year.max() + 1 + forecast_steps), forecast_values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xticks(np.arange(2013, 2026, 1))
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Real estate renting and business activities for 2021-2025:
# 2021-01-01   -1203.627961
# 2022-01-01   -2350.002450
# 2023-01-01   -3362.753801
# 2024-01-01   -4257.457327
# 2025-01-01   -5047.872861
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Forecasted registrations for Manufacturing for 2021-2025:
# 2021-01-01    419.348332
# 2022-01-01    173.017164
# 2023-01-01    332.973171
# 2024-01-01    229.105177
# 2025-01-01    296.552223
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# Forecasted registrations for Construction for 2021-2025:
# 2021-01-01    271.734508
# 2022-01-01    198.997710
# 2023-01-01    221.730229
# 2024-01-01    214.625608
# 2025-01-01    216.846024
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Forecasted registrations for Agriculture & allied for 2021-2025:
# 2021-01-01    260.275497
# 2022-01-01    102.690676
# 2023-01-01    210.530964
# 2024-01-01    136.732437
# 2025-01-01    187.235108
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Forecasted registrations for Wholesale and retail trade repair of motor vehicles motorcycles and personal and household goods for 2021-2025:
# 2021-01-01    150.054904
# 2022-01-01    119.968107
# 2023-01-01    127.092707
# 2024-01-01    125.405591
# 2025-01-01    125.805102
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
