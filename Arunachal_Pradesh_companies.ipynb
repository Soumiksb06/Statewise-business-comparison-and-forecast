# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/set_project_2/data/ArunachalPradesh1.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#     CORPORATE_IDENTIFICATION_NUMBER  \
# 0             U01100AR2016PTC013438
# 1             U01100AR2017PTC013482
# 2             U01100AR2017PTC013495
# 3             U01100AR2017PTC013496
# 4             U01100AR2017PTC013498
# ..                              ...
# 692           U93090AR2017PTC013494
# 693           U93090AR2018PTC013538
# 694           U93090AR2019PTC013571
# 695           U96000AR2020PTC013617
# 696           U99999AR1947PLC027443
#
#                                           Company_Name  \
# 0                 PANIOR PARE PRODUCER COMPANY LIMITED
# 1        LOHIT ORGANIC FARMERS PRODUCER COMPANYLIMITED
# 2               AALO FOODS & BEVERAGES PRIVATE LIMITED
# 3    HIPOHIGI ORGANIC PINEAPPLE PRODUCERCOMPANY LIM...
# 4             ABOTANI ORGANIC PRODUCER COMPANY LIMITED
# ..                                                 ...
# 692              JORAM DOL ENTERPRISES PRIVATE LIMITED
# 693        FAR-EAST TOURISM DEVELOPMENT PRIVATELIMITED
# 694      FLYING MONALS EVENT MANAGEMENT PRIVATELIMITED
# 695                           NE ROOTS PRIVATE LIMITED
# 696                       HINDUSTAN UMBREALLAS LIMITED
#
#                 Company_status Company_class              Company_Category  \
# 0                       Active       Private     Company limited by Shares
# 1                       Active       Private     Company limited by Shares
# 2                       Active       Private     Company limited by Shares
# 3                       Active       Private     Company limited by Shares
# 4                       Active       Private     Company limited by Shares
# ..                         ...           ...                           ...
# 692                     Active       Private     Company limited by Shares
# 693                     Active       Private     Company limited by Shares
# 694                     Active       Private     Company limited by Shares
# 695                     Active       Private     Company limited by Shares
# 696  Not Available for eFiling        Public  Company Limited by Guarantee
#
#     Company_sub_category DATE_OF_REGISTRATION   REGISTERED_STATE  \
# 0       Non-govt company           10-11-2016  Arunachal Pradesh
# 1       Non-govt company           09-06-2017  Arunachal Pradesh
# 2       Non-govt company           15-09-2017  Arunachal Pradesh
# 3       Non-govt company           20-09-2017  Arunachal Pradesh
# 4       Non-govt company           13-10-2017  Arunachal Pradesh
# ..                   ...                  ...                ...
# 692     Non-govt company           14-09-2017  Arunachal Pradesh
# 693     Non-govt company           26-10-2018  Arunachal Pradesh
# 694     Non-govt company           12-12-2019  Arunachal Pradesh
# 695     Non-govt company           23-10-2020  Arunachal Pradesh
# 696     Non-govt company           13-05-1947  Arunachal Pradesh
#
#      AUTHORIZED_CAP  PAIDUP_CAPITAL  Industrial_Class  \
# 0           5000000          384000              1100
# 1          18500000         4115000              1100
# 2           2000000         2000000              1100
# 3            100000          100000              1100
# 4           1000000          200000              1100
# ..              ...             ...               ...
# 692         1000000          300000             93090
# 693        20000000        10000010             93090
# 694         1000000          200000             93090
# 695         1000000           20000             96000
# 696               0               0             99999
#
#                 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0    Agriculture, hunting and related service activ...
# 1    Agriculture, hunting and related service activ...
# 2    Agriculture, hunting and related service activ...
# 3    Agriculture, hunting and related service activ...
# 4    Agriculture, hunting and related service activ...
# ..                                                 ...
# 692  Other community, social and personal service a...
# 693  Other community, social and personal service a...
# 694  Other community, social and personal service a...
# 695  Activities of private households as employers ...
# 696          Extraterritorial organizations and bodies
#
#                              Registered_Office_Address REGISTRAR_OF_COMPANIES  \
# 0    Tasing Apartment, Block No.102, Upper Polo Col...           RoC-Shillong
# 1    C/O SHRI BARITLUM AMA, VILL: MARUBA PO: WAKRO,...           RoC-Shillong
# 2    UPPER COLONY, BEHIND OFFICIAL RESIDENCE OF ADC...           RoC-Shillong
# 3    Yodimomen Aalo West Siang , West Siang Unclass...           RoC-Shillong
# 4    FIRST FLOOR, E-87 , PAKAM-II NEAR MIDDLE SCHOO...           RoC-Shillong
# ..                                                 ...                    ...
# 692  2ND FLOOR, DAWNLAND HOTEL, RCC GANGA MARKET, I...           RoC-Shillong
# 693  Far-East Tourism Development Private Limited C...           RoC-Shillong
# 694  Chimpu-I/OBT Capital ESD IV CAPITAL ESD IV , P...           RoC-Shillong
# 695  C/O KANA PULU, MAYU, ROING ELECTRICAL SUB DIVI...           RoC-Shillong
# 696                    , Dibang Valley Unclassified AR           RoC-Shillong
#
#                         EMAIL_ADDR Latest_Year_AR Latest_Year_BS
# 0         mbordoloi@tatatrusts.org     31-03-2020     31-03-2020
# 1          lofpclwakro17@gmail.com     31-03-2020     31-03-2020
# 2              mkpoddar2@gmail.com     31-03-2018     31-03-2018
# 3             amiyasabat@gmail.com     31-03-2018     31-03-2018
# 4           johnyytaali7@gmail.com     31-03-2020     31-03-2020
# ..                             ...            ...            ...
# 692           anujoram08@gmail.com            NaN            NaN
# 693           tamchitadh@gmail.com     31-03-2020     31-03-2020
# 694  flyingmonalsevent19@gmail.com            NaN            NaN
# 695             amyaango@gmail.com            NaN            NaN
# 696                            NaN            NaN            NaN
#
# [697 rows x 17 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER             0
# Company_Name                                0
# Company_status                              0
# Company_class                               0
# Company_Category                            0
# Company_sub_category                        0
# DATE_OF_REGISTRATION                        0
# REGISTERED_STATE                            0
# AUTHORIZED_CAP                              0
# PAIDUP_CAPITAL                              0
# Industrial_Class                            0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN      0
# Registered_Office_Address                   0
# REGISTRAR_OF_COMPANIES                      0
# EMAIL_ADDR                                208
# Latest_Year_AR                            437
# Latest_Year_BS                            438
# Registration_Year                           0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#     CORPORATE_IDENTIFICATION_NUMBER  \
# 0             U01100AR2016PTC013438
# 1             U01100AR2017PTC013482
# 2             U01100AR2017PTC013495
# 3             U01100AR2017PTC013496
# 4             U01100AR2017PTC013498
# ..                              ...
# 692           U93090AR2017PTC013494
# 693           U93090AR2018PTC013538
# 694           U93090AR2019PTC013571
# 695           U96000AR2020PTC013617
# 696           U99999AR1947PLC027443
#
#                                           Company_Name  \
# 0                 PANIOR PARE PRODUCER COMPANY LIMITED
# 1        LOHIT ORGANIC FARMERS PRODUCER COMPANYLIMITED
# 2               AALO FOODS & BEVERAGES PRIVATE LIMITED
# 3    HIPOHIGI ORGANIC PINEAPPLE PRODUCERCOMPANY LIM...
# 4             ABOTANI ORGANIC PRODUCER COMPANY LIMITED
# ..                                                 ...
# 692              JORAM DOL ENTERPRISES PRIVATE LIMITED
# 693        FAR-EAST TOURISM DEVELOPMENT PRIVATELIMITED
# 694      FLYING MONALS EVENT MANAGEMENT PRIVATELIMITED
# 695                           NE ROOTS PRIVATE LIMITED
# 696                       HINDUSTAN UMBREALLAS LIMITED
#
#                 Company_status Company_class              Company_Category  \
# 0                       Active       Private     Company limited by Shares
# 1                       Active       Private     Company limited by Shares
# 2                       Active       Private     Company limited by Shares
# 3                       Active       Private     Company limited by Shares
# 4                       Active       Private     Company limited by Shares
# ..                         ...           ...                           ...
# 692                     Active       Private     Company limited by Shares
# 693                     Active       Private     Company limited by Shares
# 694                     Active       Private     Company limited by Shares
# 695                     Active       Private     Company limited by Shares
# 696  Not Available for eFiling        Public  Company Limited by Guarantee
#
#     Company_sub_category   REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0       Non-govt company  Arunachal Pradesh         5000000          384000
# 1       Non-govt company  Arunachal Pradesh        18500000         4115000
# 2       Non-govt company  Arunachal Pradesh         2000000         2000000
# 3       Non-govt company  Arunachal Pradesh          100000          100000
# 4       Non-govt company  Arunachal Pradesh         1000000          200000
# ..                   ...                ...             ...             ...
# 692     Non-govt company  Arunachal Pradesh         1000000          300000
# 693     Non-govt company  Arunachal Pradesh        20000000        10000010
# 694     Non-govt company  Arunachal Pradesh         1000000          200000
# 695     Non-govt company  Arunachal Pradesh         1000000           20000
# 696     Non-govt company  Arunachal Pradesh               0               0
#
#      Industrial_Class             PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                1100  Agriculture, hunting and related service activ...
# 1                1100  Agriculture, hunting and related service activ...
# 2                1100  Agriculture, hunting and related service activ...
# 3                1100  Agriculture, hunting and related service activ...
# 4                1100  Agriculture, hunting and related service activ...
# ..                ...                                                ...
# 692             93090  Other community, social and personal service a...
# 693             93090  Other community, social and personal service a...
# 694             93090  Other community, social and personal service a...
# 695             96000  Activities of private households as employers ...
# 696             99999          Extraterritorial organizations and bodies
#
#                              Registered_Office_Address REGISTRAR_OF_COMPANIES  \
# 0    Tasing Apartment, Block No.102, Upper Polo Col...           RoC-Shillong
# 1    C/O SHRI BARITLUM AMA, VILL: MARUBA PO: WAKRO,...           RoC-Shillong
# 2    UPPER COLONY, BEHIND OFFICIAL RESIDENCE OF ADC...           RoC-Shillong
# 3    Yodimomen Aalo West Siang , West Siang Unclass...           RoC-Shillong
# 4    FIRST FLOOR, E-87 , PAKAM-II NEAR MIDDLE SCHOO...           RoC-Shillong
# ..                                                 ...                    ...
# 692  2ND FLOOR, DAWNLAND HOTEL, RCC GANGA MARKET, I...           RoC-Shillong
# 693  Far-East Tourism Development Private Limited C...           RoC-Shillong
# 694  Chimpu-I/OBT Capital ESD IV CAPITAL ESD IV , P...           RoC-Shillong
# 695  C/O KANA PULU, MAYU, ROING ELECTRICAL SUB DIVI...           RoC-Shillong
# 696                    , Dibang Valley Unclassified AR           RoC-Shillong
#
#     Latest_Year_AR Latest_Year_BS  Registration_Year
# 0       31-03-2020     31-03-2020               2016
# 1       31-03-2020     31-03-2020               2017
# 2       31-03-2018     31-03-2018               2017
# 3       31-03-2018     31-03-2018               2017
# 4       31-03-2020     31-03-2020               2017
# ..             ...            ...                ...
# 692            NaN            NaN               2017
# 693     31-03-2020     31-03-2020               2018
# 694            NaN            NaN               2019
# 695            NaN            NaN               2020
# 696            NaN            NaN               1947
#
# [697 rows x 16 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='Company_status', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Industrial_Class', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'Company_Category' column
print(df['Company_Category'].unique())
# Out:
# ['Company limited by Shares' 'Unlimited Company'
#  'Company Limited by Guarantee']

# %%
import numpy as np
df['Company_Category'] =df['Company_Category'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Company_Category', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Agriculture, hunting and related service activities    50
# Construction                                           42
# Other business activities                              31
# Transport, storage and communications                  11
# Computer and related activities                        11
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# # Model

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame
# Convert 'Latest_Year_AR' to datetime format
df['Latest_Year_AR'] = pd.to_datetime(df['Latest_Year_AR'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = [
    'Agriculture, hunting and related service activities',
    'Construction',
    'Other business activities',
    'Transport, storage and communications',
    'Computer and related activities'
]

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index.year, y.values, marker='o', label='Historical Data')
    plt.plot(range(y.index.year.max() + 1, y.index.year.max() + 1 + forecast_steps), forecast_values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xticks(np.arange(2013, 2026, 1))
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Forecasted registrations for Agriculture, hunting and related service activities for 2021-2025:
# 2021-01-01     9.476982
# 2022-01-01    14.142824
# 2023-01-01    11.856776
# 2024-01-01    12.976834
# 2025-01-01    12.428057
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# Forecasted registrations for Construction for 2021-2025:
# 2021-01-01    7.219804
# 2022-01-01    6.731386
# 2023-01-01    6.425627
# 2024-01-01    6.234216
# 2025-01-01    6.114388
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Forecasted registrations for Other business activities for 2021-2025:
# 6     4.312245
# 7     4.455806
# 8     4.521811
# 9     4.552159
# 10    4.566111
# Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Forecasted registrations for Transport, storage and communications for 2021-2025:
# 5    2.158379
# 6    2.182384
# 7    2.186022
# 8    2.186573
# 9    2.186657
# Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for ARMA and trend. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Forecasted registrations for Computer and related activities for 2021-2025:
# 4    2.530609
# 5    2.618914
# 6    2.633610
# 7    2.636056
# 8    2.636463
# Name: predicted_mean, dtype: float64
