# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/set_project_2/data/Goa.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L00012GA1965PLC000199
# 1              L00222GA1966PLC000067
# 2              L23109GA1967PLC000076
# 3              L24111GA1963PLC000562
# 4              L24233GA1985PLC001587
# ...                              ...
# 9428           U94413GA2002PTC003135
# 9429           U95000GA2020OPC014297
# 9430           U99090GA2001PTC002951
# 9431           U99999GA1985PTC004763
# 9432           U99999GA1991PTC005564
#
#                                   Company_Name                 Company_status  \
# 0                      MANDOVI PELLETS LIMITED                    Amalgamated
# 1                      ARLEM BREWERIES LIMITED                    Amalgamated
# 2                           GOA CARBON LIMITED                         Active
# 3                     THE SOUTHERN GAS LIMITED                         Active
# 4                SANDU PHARMACEUTICALS LIMITED                         Active
# ...                                        ...                            ...
# 9428      GOMES SPORTS ACADEMY PRIVATE LIMITED  Under Process of Striking off
# 9429    TRINETH SERVICES (OPC) PRIVATE LIMITED                         Active
# 9430          MEDIA PROMOTIONS PRIVATE LIMITED                         Active
# 9431                MC-BAUCHEMIE INDIA PVT LTD                         Active
# 9432  SRI SANTHIPRIYA MINERALS PRIVATE LIMITED                         Active
#
#                     Company_class           Company_Category  \
# 0                          Public  Company limited by Shares
# 1                          Public  Company limited by Shares
# 2                          Public  Company limited by Shares
# 3                          Public  Company limited by Shares
# 4                          Public  Company limited by Shares
# ...                           ...                        ...
# 9428                      Private  Company limited by Shares
# 9429  Private(One Person Company)  Company limited by Shares
# 9430                      Private  Company limited by Shares
# 9431                      Private  Company limited by Shares
# 9432                      Private  Company limited by Shares
#
#      Company_sub_category DATE_OF_REGISTRATION REGISTERED_STATE  \
# 0        Non-govt company             12-04-65              Goa
# 1        Non-govt company             21-09-66              Goa
# 2        Non-govt company             22-06-67              Goa
# 3        Non-govt company             29-07-63              Goa
# 4        Non-govt company             15-11-85              Goa
# ...                   ...                  ...              ...
# 9428     Non-govt company             06-09-02              Goa
# 9429     Non-govt company             20-02-20              Goa
# 9430     Non-govt company             09-02-01              Goa
# 9431     Non-govt company             24-01-85              Goa
# 9432     Non-govt company             31-07-91              Goa
#
#       AUTHORIZED_CAP  PAIDUP_CAPITAL  Industrial_Class  \
# 0         1000000000             0.0                12
# 1           20000000             0.0               222
# 2          250000000      91510520.0             23109
# 3            5000000       2250000.0             24111
# 4          100000000      70810000.0             24233
# ...              ...             ...               ...
# 9428          100000        100000.0             94413
# 9429          100000        100000.0             95000
# 9430          500000        201000.0             99090
# 9431        50000000      37620000.0             99999
# 9432         4500000       4200000.0             99999
#
#                  PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                                          Unclassified
# 1                                          Unclassified
# 2     Manufacture of coke, refined petroleum product...
# 3        Manufacture of chemicals and chemical products
# 4        Manufacture of chemicals and chemical products
# ...                                                 ...
# 9428                                       Unclassified
# 9429  Activities of private households as employers ...
# 9430          Extraterritorial organizations and bodies
# 9431          Extraterritorial organizations and bodies
# 9432          Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     CHOWGULE HOUSE, MORMUGAO HARBOUR, HARBOUR , Un...
# 1     CHOWGULE HOUSE, MORMUGAO HARBOUR 403803. GOA. ...
# 2     DEMPO HOUSECAMPAL PANAJI GOA , Unclassified GA...
# 3     MEERA CLASSIC, PHASE II, GOGOL, BORDA, POST FA...
# 4     PLOT NO.25,26,29 & 30,PILERNE INDUSTRIAL ESTAT...
# ...                                                 ...
# 9428  GOMES HERITAGEGAURA VADDO CALANGUTE BARDEZ GOA...
# 9429  HOUSE NO-13F COTTAMOL, CUNCOLIM , South Goa Un...
# 9430  7TH FLOOR ROOM NO 703DEMPO TRADE CENTRE PANAJI...
# 9431  Plot no. 148 & I49, Kundaim lndustrial Estate,...
# 9432  CHOWGULE HOUSE MORMUGAO HARBOUR , Unclassified...
#
#      REGISTRAR_OF_COMPANIES                   EMAIL_ADDR Latest_Year_AR  \
# 0                   RoC-Goa                          NaN            NaN
# 1                   RoC-Goa                          NaN            NaN
# 2                   RoC-Goa         pravin@goacarbon.com       31-03-20
# 3                   RoC-Goa  sglgoa@southerngasindia.com       31-03-20
# 4                   RoC-Goa            corp.sec@sandu.in       31-03-20
# ...                     ...                          ...            ...
# 9428                RoC-Goa                          NaN            NaN
# 9429                RoC-Goa       CLIENT@LEGALRAASTA.COM            NaN
# 9430                RoC-Goa        accounts@mediagoa.com       31-03-20
# 9431                RoC-Goa  info.india@mc-bauchemie.com       31-03-20
# 9432                RoC-Goa   mangoli.cil@chowgule.co.in       31-03-20
#
#      Latest_Year_BS
# 0               NaN
# 1               NaN
# 2          31-03-20
# 3          31-03-20
# 4          31-03-20
# ...             ...
# 9428            NaN
# 9429            NaN
# 9430       31-03-20
# 9431       31-03-20
# 9432       31-03-20
#
# [9433 rows x 17 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER              0
# Company_Name                                 0
# Company_status                               0
# Company_class                                1
# Company_Category                             1
# Company_sub_category                         1
# DATE_OF_REGISTRATION                         0
# REGISTERED_STATE                             0
# AUTHORIZED_CAP                               0
# PAIDUP_CAPITAL                               0
# Industrial_Class                             0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN       0
# Registered_Office_Address                    0
# REGISTRAR_OF_COMPANIES                       0
# EMAIL_ADDR                                1973
# Latest_Year_AR                            4048
# Latest_Year_BS                            4046
# Registration_Year                            0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L00012GA1965PLC000199
# 1              L00222GA1966PLC000067
# 2              L23109GA1967PLC000076
# 3              L24111GA1963PLC000562
# 4              L24233GA1985PLC001587
# ...                              ...
# 9428           U94413GA2002PTC003135
# 9429           U95000GA2020OPC014297
# 9430           U99090GA2001PTC002951
# 9431           U99999GA1985PTC004763
# 9432           U99999GA1991PTC005564
#
#                                   Company_Name                 Company_status  \
# 0                      MANDOVI PELLETS LIMITED                    Amalgamated
# 1                      ARLEM BREWERIES LIMITED                    Amalgamated
# 2                           GOA CARBON LIMITED                         Active
# 3                     THE SOUTHERN GAS LIMITED                         Active
# 4                SANDU PHARMACEUTICALS LIMITED                         Active
# ...                                        ...                            ...
# 9428      GOMES SPORTS ACADEMY PRIVATE LIMITED  Under Process of Striking off
# 9429    TRINETH SERVICES (OPC) PRIVATE LIMITED                         Active
# 9430          MEDIA PROMOTIONS PRIVATE LIMITED                         Active
# 9431                MC-BAUCHEMIE INDIA PVT LTD                         Active
# 9432  SRI SANTHIPRIYA MINERALS PRIVATE LIMITED                         Active
#
#                     Company_class           Company_Category  \
# 0                          Public  Company limited by Shares
# 1                          Public  Company limited by Shares
# 2                          Public  Company limited by Shares
# 3                          Public  Company limited by Shares
# 4                          Public  Company limited by Shares
# ...                           ...                        ...
# 9428                      Private  Company limited by Shares
# 9429  Private(One Person Company)  Company limited by Shares
# 9430                      Private  Company limited by Shares
# 9431                      Private  Company limited by Shares
# 9432                      Private  Company limited by Shares
#
#      Company_sub_category REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0        Non-govt company              Goa      1000000000             0.0
# 1        Non-govt company              Goa        20000000             0.0
# 2        Non-govt company              Goa       250000000      91510520.0
# 3        Non-govt company              Goa         5000000       2250000.0
# 4        Non-govt company              Goa       100000000      70810000.0
# ...                   ...              ...             ...             ...
# 9428     Non-govt company              Goa          100000        100000.0
# 9429     Non-govt company              Goa          100000        100000.0
# 9430     Non-govt company              Goa          500000        201000.0
# 9431     Non-govt company              Goa        50000000      37620000.0
# 9432     Non-govt company              Goa         4500000       4200000.0
#
#       Industrial_Class             PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                   12                                       Unclassified
# 1                  222                                       Unclassified
# 2                23109  Manufacture of coke, refined petroleum product...
# 3                24111     Manufacture of chemicals and chemical products
# 4                24233     Manufacture of chemicals and chemical products
# ...                ...                                                ...
# 9428             94413                                       Unclassified
# 9429             95000  Activities of private households as employers ...
# 9430             99090          Extraterritorial organizations and bodies
# 9431             99999          Extraterritorial organizations and bodies
# 9432             99999          Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     CHOWGULE HOUSE, MORMUGAO HARBOUR, HARBOUR , Un...
# 1     CHOWGULE HOUSE, MORMUGAO HARBOUR 403803. GOA. ...
# 2     DEMPO HOUSECAMPAL PANAJI GOA , Unclassified GA...
# 3     MEERA CLASSIC, PHASE II, GOGOL, BORDA, POST FA...
# 4     PLOT NO.25,26,29 & 30,PILERNE INDUSTRIAL ESTAT...
# ...                                                 ...
# 9428  GOMES HERITAGEGAURA VADDO CALANGUTE BARDEZ GOA...
# 9429  HOUSE NO-13F COTTAMOL, CUNCOLIM , South Goa Un...
# 9430  7TH FLOOR ROOM NO 703DEMPO TRADE CENTRE PANAJI...
# 9431  Plot no. 148 & I49, Kundaim lndustrial Estate,...
# 9432  CHOWGULE HOUSE MORMUGAO HARBOUR , Unclassified...
#
#      REGISTRAR_OF_COMPANIES Latest_Year_AR Latest_Year_BS  Registration_Year
# 0                   RoC-Goa            NaN            NaN               2065
# 1                   RoC-Goa            NaN            NaN               2066
# 2                   RoC-Goa       31-03-20       31-03-20               2067
# 3                   RoC-Goa       31-03-20       31-03-20               2063
# 4                   RoC-Goa       31-03-20       31-03-20               1985
# ...                     ...            ...            ...                ...
# 9428                RoC-Goa            NaN            NaN               2002
# 9429                RoC-Goa            NaN            NaN               2020
# 9430                RoC-Goa       31-03-20       31-03-20               2001
# 9431                RoC-Goa       31-03-20       31-03-20               1985
# 9432                RoC-Goa       31-03-20       31-03-20               1991
#
# [9433 rows x 16 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='Company_status', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Industrial_Class', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'Company_Category' column
print(df['Company_Category'].unique())
# Out:
# ['Company limited by Shares' 'Unlimited Company'
#  'Company Limited by Guarantee' nan]

# %%
import numpy as np
df['Company_Category'] =df['Company_Category'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Company_Category', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Other business activities                                  673
# Hotels and restaurants                                     260
# Computer and related activities                            218
# Other community, social and personal service activities    145
# Transport, storage and communications                      125
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# # Model

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame
# Convert 'Latest_Year_AR' to datetime format
df['Latest_Year_AR'] = pd.to_datetime(df['Latest_Year_AR'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = [
    'Other business activities',
    'Hotels and restaurants',
    'Computer and related activities',
    'Other community, social and personal service activities',
    'Transport, storage and communications'
]

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index.year, y.values, marker='o', label='Historical Data')
    plt.plot(range(y.index.year.max() + 1, y.index.year.max() + 1 + forecast_steps), forecast_values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xticks(np.arange(2013, 2026, 1))
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Other business activities for 2021-2025:
# 2021-01-01    56.103142
# 2022-01-01    55.962950
# 2023-01-01    55.941036
# 2024-01-01    55.937611
# 2025-01-01    55.937075
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# Forecasted registrations for Hotels and restaurants for 2021-2025:
# 2021-01-01    52.522446
# 2022-01-01    54.627444
# 2023-01-01    55.885383
# 2024-01-01    56.637122
# 2025-01-01    57.086358
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Computer and related activities for 2021-2025:
# 2021-01-01    42.450653
# 2022-01-01    42.652411
# 2023-01-01    42.626137
# 2024-01-01    42.629559
# 2025-01-01    42.629113
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Other community, social and personal service activities for 2021-2025:
# 2021-01-01    31.909506
# 2022-01-01    21.768483
# 2023-01-01    30.403631
# 2024-01-01    23.050746
# 2025-01-01    29.311776
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# Forecasted registrations for Transport, storage and communications for 2021-2025:
# 2021-01-01    24.346991
# 2022-01-01    24.310167
# 2023-01-01    24.314075
# 2024-01-01    24.313660
# 2025-01-01    24.313704
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
