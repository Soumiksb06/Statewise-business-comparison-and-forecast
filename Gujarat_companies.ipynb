# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/set_project_2/data/Gujarat.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER                   Company_Name  \
# 0                L01110GJ1991PLC015846       AMRAWORLD AGRICO LIMITED
# 1                L01110GJ1994PLC021066     TRANS TECHNO FOODS LIMITED
# 2                L01110GJ1994PLC021368  GALAXY AGRICO EXPORTS LIMITED
# 3                L01110GJ1996PLC029329   CHEMCRUX ENTERPRISES LIMITED
# 4                L01111GJ2011PLC068414      JIYA ECO-PRODUCTS LIMITED
# ...                                ...                            ...
# 115020           U29199GJ2000PTC001266                    ACCUMAX LTD
# 115021           U51909GJ1945PLC000780        SHREE LAXMI AGENTS LTD.
# 115022           U65993GJ2000PTC000444        BANNER INVESTMENTS LTD.
# 115023           U65993GJ2000PTC003316      MISHAPAR INVESTMENTS LTD.
# 115024           U99999GJ2000PTC006960    BALGOVIND AND SONS PVT.LTD.
#
#                    Company_status Company_class              Company_Category  \
# 0                          Active        Public     Company limited by Shares
# 1               Under liquidation        Public     Company limited by Shares
# 2                          Active        Public     Company limited by Shares
# 3                          Active        Public     Company limited by Shares
# 4                          Active        Public     Company limited by Shares
# ...                           ...           ...                           ...
# 115020                 Strike Off        Public  Company Limited by Guarantee
# 115021  Not Available for eFiling        Public  Company Limited by Guarantee
# 115022                 Strike Off        Public  Company Limited by Guarantee
# 115023  Not Available for eFiling        Public  Company Limited by Guarantee
# 115024                 Strike Off       Private  Company Limited by Guarantee
#
#        Company_sub_category DATE_OF_REGISTRATION REGISTERED_STATE  \
# 0          Non-govt company             21-06-91          Gujarat
# 1          Non-govt company             17-01-94          Gujarat
# 2          Non-govt company             23-02-94          Gujarat
# 3          Non-govt company             15-04-96          Gujarat
# 4          Non-govt company             27-12-11          Gujarat
# ...                     ...                  ...              ...
# 115020     Non-govt company                  NaN          Gujarat
# 115021     Non-govt company                  NaN          Gujarat
# 115022     Non-govt company                  NaN          Gujarat
# 115023     Non-govt company                  NaN          Gujarat
# 115024     Non-govt company                  NaN          Gujarat
#
#         AUTHORIZED_CAP  PAIDUP_CAPITAL Industrial_Class  \
# 0          130000000.0     120300000.0             1110
# 1          220000000.0     211200000.0             1110
# 2           55000000.0      27316200.0             1110
# 3           60000000.0      49362800.0             1110
# 4          320000000.0     300732620.0             1111
# ...                ...             ...              ...
# 115020             0.0             0.0            29199
# 115021             0.0             0.0            51909
# 115022             0.0             0.0            65993
# 115023             0.0             0.0            65993
# 115024             0.0             0.0            99999
#
#                    PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0       Agriculture, hunting and related service activ...
# 1       Agriculture, hunting and related service activ...
# 2       Agriculture, hunting and related service activ...
# 3       Agriculture, hunting and related service activ...
# 4       Agriculture, hunting and related service activ...
# ...                                                   ...
# 115020      Manufacture of machinery and equipment n.e.c.
# 115021  Wholesale trade and commission trade, except o...
# 115022                           Financial intermediation
# 115023                           Financial intermediation
# 115024          Extraterritorial organizations and bodies
#
#                                 Registered_Office_Address  \
# 0       24, LAXMI CHAMBERS, NAVJEEVAN PRESS ROAD, OPP....
# 1       B-2 SARITA DARSHAN OPP JAIHIND PRESS ASHRAM RO...
# 2       236, Jai Kishan Industrial Estate, Behind Murl...
# 3       330, TRIVIA Complex, Natubhai Circle, Racecour...
# 4       SURVEY NO. 202/2/1, NAVAGAM (G), TALUKA VALLAB...
# ...                                                   ...
# 115020                                  , Unclassified GJ
# 115021                                     , Unclassified
# 115022                                  , Unclassified GJ
# 115023                                     , Unclassified
# 115024                                  , Unclassified GJ
#
#        REGISTRAR_OF_COMPANIES                 EMAIL_ADDR Latest_Year_AR  \
# 0               RoC-Ahmedabad  amraworldagrico@gmail.com       31-03-20
# 1               RoC-Ahmedabad     anish_shahcs@yahoo.com       31-03-09
# 2               RoC-Ahmedabad      info@galaxyagrico.com       31-03-20
# 3               RoC-Ahmedabad    girishshah@chemcrux.com       31-03-20
# 4               RoC-Ahmedabad            cfo@jiyaeco.com       31-03-19
# ...                       ...                        ...            ...
# 115020          RoC-Ahmedabad                        NaN            NaN
# 115021          RoC-Ahmedabad                        NaN            NaN
# 115022          RoC-Ahmedabad                        NaN            NaN
# 115023          RoC-Ahmedabad                        NaN            NaN
# 115024          RoC-Ahmedabad                        NaN            NaN
#
#        Latest_Year_BS
# 0            31-03-20
# 1            31-03-06
# 2            31-03-20
# 3            31-03-20
# 4            31-03-19
# ...               ...
# 115020            NaN
# 115021            NaN
# 115022            NaN
# 115023            NaN
# 115024            NaN
#
# [115025 rows x 17 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_8652/348113690.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)
# C:\Users\ritti\AppData\Local\Temp/ipykernel_8652/348113690.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER               0
# Company_Name                                  0
# Company_status                                0
# Company_class                                 5
# Company_Category                              5
# Company_sub_category                          5
# DATE_OF_REGISTRATION                          0
# REGISTERED_STATE                              0
# AUTHORIZED_CAP                                0
# PAIDUP_CAPITAL                                0
# Industrial_Class                              0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN        0
# Registered_Office_Address                     0
# REGISTRAR_OF_COMPANIES                        0
# EMAIL_ADDR                                23553
# Latest_Year_AR                            45270
# Latest_Year_BS                            45207
# Registration_Year                             0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#        CORPORATE_IDENTIFICATION_NUMBER  \
# 0                L01110GJ1991PLC015846
# 1                L01110GJ1994PLC021066
# 2                L01110GJ1994PLC021368
# 3                L01110GJ1996PLC029329
# 4                L01111GJ2011PLC068414
# ...                                ...
# 115013           U99999GJ2001PLC062239
# 115014           U99999GJ2001PTC049257
# 115015           U99999GJ2005PTC047236
# 115016           UU3511GJ1999PTC036968
# 115017           UU5190GJ1994PTC022062
#
#                                     Company_Name     Company_status  \
# 0                       AMRAWORLD AGRICO LIMITED             Active
# 1                     TRANS TECHNO FOODS LIMITED  Under liquidation
# 2                  GALAXY AGRICO EXPORTS LIMITED             Active
# 3                   CHEMCRUX ENTERPRISES LIMITED             Active
# 4                      JIYA ECO-PRODUCTS LIMITED             Active
# ...                                          ...                ...
# 115013    ADITYA BIRLA INSURANCE BROKERS LIMITED             Active
# 115014   AKASH PALACE DEVELOPERS PRIVATE LIMITED         Strike Off
# 115015  AQUAPROOF WALLCARE INDIA PRIVATE LIMITED             Active
# 115016             EXPO SHIPPING PRIVATE LIMITED         Strike Off
# 115017               ZEAL OVERSEAS IMPEX PVT LTD         Strike Off
#
#        Company_class           Company_Category Company_sub_category  \
# 0             Public  Company limited by Shares     Non-govt company
# 1             Public  Company limited by Shares     Non-govt company
# 2             Public  Company limited by Shares     Non-govt company
# 3             Public  Company limited by Shares     Non-govt company
# 4             Public  Company limited by Shares     Non-govt company
# ...              ...                        ...                  ...
# 115013        Public  Company limited by Shares     Non-govt company
# 115014       Private  Company limited by Shares     Non-govt company
# 115015       Private  Company limited by Shares     Non-govt company
# 115016       Private  Company limited by Shares     Non-govt company
# 115017       Private  Company limited by Shares     Non-govt company
#
#        REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL Industrial_Class  \
# 0               Gujarat     130000000.0     120300000.0             1110
# 1               Gujarat     220000000.0     211200000.0             1110
# 2               Gujarat      55000000.0      27316200.0             1110
# 3               Gujarat      60000000.0      49362800.0             1110
# 4               Gujarat     320000000.0     300732620.0             1111
# ...                 ...             ...             ...              ...
# 115013          Gujarat      55000000.0      51300000.0            99999
# 115014          Gujarat       3000000.0        100000.0            99999
# 115015          Gujarat      30000000.0      30000000.0            99999
# 115016          Gujarat        100000.0           200.0            U3511
# 115017          Gujarat        500000.0           500.0            U5190
#
#                    PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0       Agriculture, hunting and related service activ...
# 1       Agriculture, hunting and related service activ...
# 2       Agriculture, hunting and related service activ...
# 3       Agriculture, hunting and related service activ...
# 4       Agriculture, hunting and related service activ...
# ...                                                   ...
# 115013          Extraterritorial organizations and bodies
# 115014          Extraterritorial organizations and bodies
# 115015          Extraterritorial organizations and bodies
# 115016                                       Unclassified
# 115017                                       Unclassified
#
#                                 Registered_Office_Address  \
# 0       24, LAXMI CHAMBERS, NAVJEEVAN PRESS ROAD, OPP....
# 1       B-2 SARITA DARSHAN OPP JAIHIND PRESS ASHRAM RO...
# 2       236, Jai Kishan Industrial Estate, Behind Murl...
# 3       330, TRIVIA Complex, Natubhai Circle, Racecour...
# 4       SURVEY NO. 202/2/1, NAVAGAM (G), TALUKA VALLAB...
# ...                                                   ...
# 115013  INDIAN RAYON COMPOUND VERAVAL , Junagadh Uncla...
# 115014  302, PRATIBHA-1, B/H SAKAR-I, NR, GANDHIGRAM R...
# 115015  156/157,GIDC,BETWEEN HALOL, NEAR GODRA,KALOL, ...
# 115016  304, DWARKESH COMPLEX,NR. WELCOME HOTEL R.C. D...
# 115017  17,ROYAL CHAMBER,GHEEKANTA,RELIEF ROAD AHMEDAB...
#
#        REGISTRAR_OF_COMPANIES Latest_Year_AR Latest_Year_BS  Registration_Year
# 0               RoC-Ahmedabad       31-03-20       31-03-20               1991
# 1               RoC-Ahmedabad       31-03-09       31-03-06               1994
# 2               RoC-Ahmedabad       31-03-20       31-03-20               1994
# 3               RoC-Ahmedabad       31-03-20       31-03-20               1996
# 4               RoC-Ahmedabad       31-03-19       31-03-19               2011
# ...                       ...            ...            ...                ...
# 115013          RoC-Ahmedabad       31-03-20       31-03-20               2001
# 115014          RoC-Ahmedabad       31-03-13       31-03-13               2001
# 115015          RoC-Ahmedabad       31-03-20       31-03-20               2005
# 115016          RoC-Ahmedabad            NaN            NaN               1999
# 115017          RoC-Ahmedabad            NaN            NaN               1994
#
# [115018 rows x 16 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='Company_status', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Industrial_Class', data=df[(df['Registration_Year'] <= 2020) & (df['Registration_Year'] >= 1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'Company_Category' column
print(df['Company_Category'].unique())
# Out:
# ['Company limited by Shares' 'Company Limited by Guarantee'
#  'Unlimited Company' nan]

# %%
import numpy as np
df['Company_Category'] =df['Company_Category'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Company_Category', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Other business activities                                                         8221
# Computer and related activities                                                   3841
# Wholesale trade and commission trade, except of motor vehicles and motorcycles    2876
# Manufacture of chemicals and chemical products                                    2374
# Construction                                                                      2171
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# # Model

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame
# Convert 'Latest_Year_AR' to datetime format
df['Latest_Year_AR'] = pd.to_datetime(df['Latest_Year_AR'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = [
    'Other business activities',
    'Computer and related activities',
    'Wholesale trade and commission trade, except of motor vehicles and motorcycles',
    'Manufacture of chemicals and chemical products',
    'Construction'
]

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index.year, y.values, marker='o', label='Historical Data')
    plt.plot(range(y.index.year.max() + 1, y.index.year.max() + 1 + forecast_steps), forecast_values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xticks(np.arange(2013, 2026, 1))
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Other business activities for 2021-2025:
# 2021-01-01    1190.596636
# 2022-01-01    1107.980905
# 2023-01-01    1168.598693
# 2024-01-01    1124.121495
# 2025-01-01    1156.755829
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Computer and related activities for 2021-2025:
# 2021-01-01    760.849167
# 2022-01-01    793.068031
# 2023-01-01    810.707281
# 2024-01-01    820.364455
# 2025-01-01    825.651584
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Wholesale trade and commission trade, except of motor vehicles and motorcycles for 2021-2025:
# 2021-01-01    591.053412
# 2022-01-01    642.278131
# 2023-01-01    684.563829
# 2024-01-01    719.470420
# 2025-01-01    748.285601
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Forecasted registrations for Manufacture of chemicals and chemical products for 2021-2025:
# 2021-01-01     823.446928
# 2022-01-01     973.422643
# 2023-01-01    1091.527539
# 2024-01-01    1184.534375
# 2025-01-01    1257.776652
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\ritti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# Forecasted registrations for Construction for 2021-2025:
# 2021-01-01    296.049054
# 2022-01-01    286.904847
# 2023-01-01    292.461111
# 2024-01-01    289.084977
# 2025-01-01    291.136406
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
