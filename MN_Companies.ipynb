# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data\Manipur.csv", encoding='ISO-8859-1',low_memory=False)

df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L65929MN1987PLC002802
# 1              U01100MN2016PTC013499
# 2              U01100MN2016PTC013508
# 3              U01100MN2017PTC013597
# 4              U01100MN2017PTC013598
# ...                              ...
# 1295           U99999MN1963PLC012805
# 1296           U99999MN1963PLC012806
# 1297           U99999MN1963PLC012807
# 1298           U99999MN1963PLC012808
# 1299           U99999MN1963PLC012809
#
#                                            Company_Name  \
# 0     NEW MILLENIUM HEALTH CARE PRODUCTS & EQUIPMENT...
# 1               BOTWAYS FARMER PRODUCER COMPANY LIMITED
# 2              SIDAYAI CHENGUM PRODUCER COMPANY LIMITED
# 3               RUWMEE ORGANIC PRODUCER COMPANY LIMITED
# 4             CHINGAREL ORGANIC PRODUCER COMPANYLIMITED
# ...                                                 ...
# 1295  KAPEESH TRANSPORT & FINANCE COMPANYPRIVATE LIM...
# 1296                 PRESTIGE BUILDERS PRIVATE LIMITED.
# 1297     STRESSED CONCRETE CONSTRUCTION PRIVATELIMITED.
# 1298                  PAELI ASSOCIATES PRIVATE LIMITED.
# 1299                               INDDABRATOR LIMITED.
#
#                  Company_status Company_class              Company_Category  \
# 0                    Strike Off        Public     Company limited by Shares
# 1                        Active       Private     Company limited by Shares
# 2                        Active       Private     Company limited by Shares
# 3                        Active       Private     Company limited by Shares
# 4                        Active       Private     Company limited by Shares
# ...                         ...           ...                           ...
# 1295  Not Available for eFiling        Public  Company Limited by Guarantee
# 1296  Not Available for eFiling        Public  Company Limited by Guarantee
# 1297  Not Available for eFiling        Public  Company Limited by Guarantee
# 1298  Not Available for eFiling        Public  Company Limited by Guarantee
# 1299  Not Available for eFiling        Public  Company Limited by Guarantee
#
#      Company_sub_category DATE_OF_REGISTRATION REGISTERED_STATE  \
# 0        Non-govt company             20-11-87          Manipur
# 1        Non-govt company             03-11-16          Manipur
# 2        Non-govt company             26-12-16          Manipur
# 3        Non-govt company             31-10-17          Manipur
# 4        Non-govt company             06-11-17          Manipur
# ...                   ...                  ...              ...
# 1295     Non-govt company             24-12-63          Manipur
# 1296     Non-govt company             24-12-63          Manipur
# 1297     Non-govt company             27-12-63          Manipur
# 1298     Non-govt company             27-12-63          Manipur
# 1299     Non-govt company             27-12-63          Manipur
#
#       AUTHORIZED_CAP  PAIDUP_CAPITAL  Industrial_Class  \
# 0          220000000       220000000             65929
# 1            1500000          200000              1100
# 2            1500000          200000              1100
# 3            1500000          200000              1100
# 4            1000000          333000              1100
# ...              ...             ...               ...
# 1295               0               0             99999
# 1296               0               0             99999
# 1297               0               0             99999
# 1298               0               0             99999
# 1299               0               0             99999
#
#                  PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                              Financial intermediation
# 1     Agriculture, hunting and related service activ...
# 2     Agriculture, hunting and related service activ...
# 3     Agriculture, hunting and related service activ...
# 4     Agriculture, hunting and related service activ...
# ...                                                 ...
# 1295          Extraterritorial organizations and bodies
# 1296          Extraterritorial organizations and bodies
# 1297          Extraterritorial organizations and bodies
# 1298          Extraterritorial organizations and bodies
# 1299          Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     DHARAMSALA ROAD, IMPHAL, , Unclassified MN 000000
# 1     KHABUNG KARONG PO&PS - SENAPATI SENAPATI , Sen...
# 2     SINGJAMEI CHINGAMAKHA MAISNAM LEIKAI IMPHAL WE...
# 3     KOMLATHABI VILLAGE CHANDEL , Chandel Unclassif...
# 4     C/O. GREEN FOUNDATION KWAKEITHEL THIYAM LEIKAI...
# ...                                                 ...
# 1295                                  , Unclassified MN
# 1296                                  , Unclassified MN
# 1297                                  , Unclassified MN
# 1298                                  , Unclassified MN
# 1299                                  , Unclassified MN
#
#      REGISTRAR_OF_COMPANIES                   EMAIL_ADDR Latest_Year_AR  \
# 0              RoC-Shillong                          NaN            NaN
# 1              RoC-Shillong    hlnhreikhenamai@gmail.com            NaN
# 2              RoC-Shillong           ougricpl@gmail.com            NaN
# 3              RoC-Shillong         thomparoel@gmail.com       31-03-20
# 4              RoC-Shillong  chingarel.organic@gmail.com       31-03-19
# ...                     ...                          ...            ...
# 1295           RoC-Shillong                          NaN            NaN
# 1296           RoC-Shillong                          NaN            NaN
# 1297           RoC-Shillong                          NaN            NaN
# 1298           RoC-Shillong                          NaN            NaN
# 1299           RoC-Shillong                          NaN            NaN
#
#      Latest_Year_BS Unnamed: 17 Unnamed: 18 Unnamed: 19
# 0               NaN
# 1               NaN         NaN         NaN         NaN
# 2               NaN         NaN         NaN         NaN
# 3          31-03-20         NaN         NaN         NaN
# 4          31-03-19         NaN         NaN         NaN
# ...             ...         ...         ...         ...
# 1295            NaN         NaN         NaN         NaN
# 1296            NaN         NaN         NaN         NaN
# 1297            NaN         NaN         NaN         NaN
# 1298            NaN         NaN         NaN         NaN
# 1299            NaN         NaN         NaN         NaN
#
# [1300 rows x 20 columns]

# %%
# Assuming df is your DataFrame

# Filter out rows with unknown or invalid values in 'DATE_OF_REGISTRATION'
df = df[pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True).notna()]

# Convert 'DATE_OF_REGISTRATION' to datetime format
df['DATE_OF_REGISTRATION'] = pd.to_datetime(df['DATE_OF_REGISTRATION'], errors='coerce', dayfirst=True)

# Extract year from the registration date
df['Registration_Year'] = df['DATE_OF_REGISTRATION'].dt.year

# %%
# Check for missing values
df.isnull().sum()
# Out:
# CORPORATE_IDENTIFICATION_NUMBER              0
# Company_Name                                 0
# Company_status                               0
# Company_class                                0
# Company_Category                             0
# Company_sub_category                         0
# DATE_OF_REGISTRATION                         0
# REGISTERED_STATE                             0
# AUTHORIZED_CAP                               0
# PAIDUP_CAPITAL                               0
# Industrial_Class                             0
# PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN       0
# Registered_Office_Address                    0
# REGISTRAR_OF_COMPANIES                       0
# EMAIL_ADDR                                 195
# Latest_Year_AR                             796
# Latest_Year_BS                             801
# Unnamed: 17                               1299
# Unnamed: 18                               1299
# Unnamed: 19                               1299
# Registration_Year                            0
# dtype: int64

# %%
df=df.drop(['DATE_OF_REGISTRATION','EMAIL_ADDR'],axis=1)
df
# Out:
#      CORPORATE_IDENTIFICATION_NUMBER  \
# 0              L65929MN1987PLC002802
# 1              U01100MN2016PTC013499
# 2              U01100MN2016PTC013508
# 3              U01100MN2017PTC013597
# 4              U01100MN2017PTC013598
# ...                              ...
# 1295           U99999MN1963PLC012805
# 1296           U99999MN1963PLC012806
# 1297           U99999MN1963PLC012807
# 1298           U99999MN1963PLC012808
# 1299           U99999MN1963PLC012809
#
#                                            Company_Name  \
# 0     NEW MILLENIUM HEALTH CARE PRODUCTS & EQUIPMENT...
# 1               BOTWAYS FARMER PRODUCER COMPANY LIMITED
# 2              SIDAYAI CHENGUM PRODUCER COMPANY LIMITED
# 3               RUWMEE ORGANIC PRODUCER COMPANY LIMITED
# 4             CHINGAREL ORGANIC PRODUCER COMPANYLIMITED
# ...                                                 ...
# 1295  KAPEESH TRANSPORT & FINANCE COMPANYPRIVATE LIM...
# 1296                 PRESTIGE BUILDERS PRIVATE LIMITED.
# 1297     STRESSED CONCRETE CONSTRUCTION PRIVATELIMITED.
# 1298                  PAELI ASSOCIATES PRIVATE LIMITED.
# 1299                               INDDABRATOR LIMITED.
#
#                  Company_status Company_class              Company_Category  \
# 0                    Strike Off        Public     Company limited by Shares
# 1                        Active       Private     Company limited by Shares
# 2                        Active       Private     Company limited by Shares
# 3                        Active       Private     Company limited by Shares
# 4                        Active       Private     Company limited by Shares
# ...                         ...           ...                           ...
# 1295  Not Available for eFiling        Public  Company Limited by Guarantee
# 1296  Not Available for eFiling        Public  Company Limited by Guarantee
# 1297  Not Available for eFiling        Public  Company Limited by Guarantee
# 1298  Not Available for eFiling        Public  Company Limited by Guarantee
# 1299  Not Available for eFiling        Public  Company Limited by Guarantee
#
#      Company_sub_category REGISTERED_STATE  AUTHORIZED_CAP  PAIDUP_CAPITAL  \
# 0        Non-govt company          Manipur       220000000       220000000
# 1        Non-govt company          Manipur         1500000          200000
# 2        Non-govt company          Manipur         1500000          200000
# 3        Non-govt company          Manipur         1500000          200000
# 4        Non-govt company          Manipur         1000000          333000
# ...                   ...              ...             ...             ...
# 1295     Non-govt company          Manipur               0               0
# 1296     Non-govt company          Manipur               0               0
# 1297     Non-govt company          Manipur               0               0
# 1298     Non-govt company          Manipur               0               0
# 1299     Non-govt company          Manipur               0               0
#
#       Industrial_Class             PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  \
# 0                65929                           Financial intermediation
# 1                 1100  Agriculture, hunting and related service activ...
# 2                 1100  Agriculture, hunting and related service activ...
# 3                 1100  Agriculture, hunting and related service activ...
# 4                 1100  Agriculture, hunting and related service activ...
# ...                ...                                                ...
# 1295             99999          Extraterritorial organizations and bodies
# 1296             99999          Extraterritorial organizations and bodies
# 1297             99999          Extraterritorial organizations and bodies
# 1298             99999          Extraterritorial organizations and bodies
# 1299             99999          Extraterritorial organizations and bodies
#
#                               Registered_Office_Address  \
# 0     DHARAMSALA ROAD, IMPHAL, , Unclassified MN 000000
# 1     KHABUNG KARONG PO&PS - SENAPATI SENAPATI , Sen...
# 2     SINGJAMEI CHINGAMAKHA MAISNAM LEIKAI IMPHAL WE...
# 3     KOMLATHABI VILLAGE CHANDEL , Chandel Unclassif...
# 4     C/O. GREEN FOUNDATION KWAKEITHEL THIYAM LEIKAI...
# ...                                                 ...
# 1295                                  , Unclassified MN
# 1296                                  , Unclassified MN
# 1297                                  , Unclassified MN
# 1298                                  , Unclassified MN
# 1299                                  , Unclassified MN
#
#      REGISTRAR_OF_COMPANIES Latest_Year_AR Latest_Year_BS Unnamed: 17  \
# 0              RoC-Shillong            NaN            NaN
# 1              RoC-Shillong            NaN            NaN         NaN
# 2              RoC-Shillong            NaN            NaN         NaN
# 3              RoC-Shillong       31-03-20       31-03-20         NaN
# 4              RoC-Shillong       31-03-19       31-03-19         NaN
# ...                     ...            ...            ...         ...
# 1295           RoC-Shillong            NaN            NaN         NaN
# 1296           RoC-Shillong            NaN            NaN         NaN
# 1297           RoC-Shillong            NaN            NaN         NaN
# 1298           RoC-Shillong            NaN            NaN         NaN
# 1299           RoC-Shillong            NaN            NaN         NaN
#
#      Unnamed: 18 Unnamed: 19  Registration_Year
# 0                                          1987
# 1            NaN         NaN               2016
# 2            NaN         NaN               2016
# 3            NaN         NaN               2017
# 4            NaN         NaN               2017
# ...          ...         ...                ...
# 1295         NaN         NaN               2063
# 1296         NaN         NaN               2063
# 1297         NaN         NaN               2063
# 1298         NaN         NaN               2063
# 1299         NaN         NaN               2063
#
# [1300 rows x 19 columns]

# %%
# EDA - Trends over time
plt.figure(figsize=(21, 9))
sns.countplot(x='Registration_Year', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Company Registrations Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# EDA - Company Status
plt.figure(figsize=(12, 5))
sns.countplot(x='Company_status', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Status')
plt.xlabel('Company Status')
plt.ylabel('Count')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
# EDA - Industrial Class Distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Industrial_Class', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)].head(10))
plt.title('Distribution of Industrial Classes')
plt.xlabel('Industrial Class')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
# EDA - Relationship between Authorized Capital and Paid-up Capital
plt.figure(figsize=(10, 6))
sns.scatterplot(x='AUTHORIZED_CAP', y='PAIDUP_CAPITAL', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Authorized Capital vs Paid-up Capital')
plt.xlabel('Authorized Capital')
plt.ylabel('Paid-up Capital')
plt.show()

# %%
# Print the unique values in the 'Company_Category' column
print(df['Company_Category'].unique())
# Out:
# ['Company limited by Shares' 'Unlimited Company'
#  'Company Limited by Guarantee']

# %%
import numpy as np
df['Company_Category'] =df['Company_Category'].replace(' ',np.nan)

# %%
# EDA - Distribution of Company Categories
plt.figure(figsize=(10, 6))
sns.countplot(x='Company_Category', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)])
plt.title('Distribution of Company Categories')
plt.xlabel('Company Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# EDA - Distribution of Principal Business Activities
plt.figure(figsize=(14, 6))
sns.countplot(x='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df[(df['Registration_Year']<=2020) & (df['Registration_Year']>=1990)], order=df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().index)
plt.title('Distribution of Principal Business Activities')
plt.xlabel('Principal Business Activity')
plt.ylabel('Count')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
# Find the top 5 business activities for each year
top_activities = df.loc[(df['Registration_Year']>=1990) & (df['Registration_Year'] <= 2020)].groupby('Registration_Year')['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].apply(lambda x: x.value_counts().nlargest(5).index.tolist())

# Filter the dataframe to include only the top activities
df_top_activities = df[df.apply(lambda x: x['Registration_Year'] in top_activities.index and x['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] in top_activities.loc[x['Registration_Year']], axis=1)]

plt.figure(figsize=(16, 8),dpi=300)
sns.countplot(x='Registration_Year', hue='PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', data=df_top_activities, palette='Set1')
plt.title('Top 5 Principal Business Activities Over Time')
plt.xlabel('Registration Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Principal Business Activity', fontsize='small')
plt.show()

# %%
# Filter companies registered between 2013 and 2020
filtered_df = df[(df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

# Get the top 5 business activities
top_business_activities = filtered_df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'].value_counts().head(5)

# Print the result
print("Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:")
print(top_business_activities)
# Out:
# Top 5 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN from 2013 to 2020:
# Other business activities                                                         192
# Agriculture, hunting and related service activities                                88
# Construction                                                                       88
# Computer and related activities                                                    68
# Wholesale trade and commission trade, except of motor vehicles and motorcycles     67
# Name: PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN, dtype: int64

# %% [markdown]
# ## Authorized capital

# %%
df.loc[:, 'AUTHORIZED_CAP'] = df['AUTHORIZED_CAP'].astype(float)
df.loc[:, 'PAIDUP_CAPITAL'] = df['PAIDUP_CAPITAL'].astype(float)
# Group by 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN' and calculate the mean of 'AUTHORIZED_CAP' and 'PAIDUP_CAPITAL'
grouped_df = df.groupby('PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN')[['AUTHORIZED_CAP', 'PAIDUP_CAPITAL']].mean().reset_index()

df = df.sort_values(by='Registration_Year')

# Calculate the percentage change in authorized capital for each activity over time
df['CAPITAL_CHANGE'] = df.groupby(['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN', 'Registration_Year'])['AUTHORIZED_CAP'].pct_change().fillna(0)

# Group by 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN' and calculate the mean of 'CAPITAL_CHANGE'
activity_trend_df = df.groupby(['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN','Registration_Year'])['CAPITAL_CHANGE'].mean().reset_index()

# Print the new DataFrame with the trend analysis
activity_trend_df2= activity_trend_df.interpolate()
activity_trend_df2
# Out:
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\1746585283.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'AUTHORIZED_CAP'] = df['AUTHORIZED_CAP'].astype(float)
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\1746585283.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'PAIDUP_CAPITAL'] = df['PAIDUP_CAPITAL'].astype(float)
#                 PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN  Registration_Year  \
# 0    Agriculture, hunting and related service activ...               1977
# 1    Agriculture, hunting and related service activ...               1979
# 2    Agriculture, hunting and related service activ...               1981
# 3    Agriculture, hunting and related service activ...               1985
# 4    Agriculture, hunting and related service activ...               1988
# ..                                                 ...                ...
# 366  Wholesale trade and commission trade, except o...               2017
# 367  Wholesale trade and commission trade, except o...               2018
# 368  Wholesale trade and commission trade, except o...               2019
# 369  Wholesale trade and commission trade, except o...               2020
# 370  Wholesale trade and commission trade, except o...               2021
#
#      CAPITAL_CHANGE
# 0          0.000000
# 1          0.000000
# 2          0.000000
# 3          0.000000
# 4          4.500000
# ..              ...
# 366        2.442857
# 367       36.300286
# 368        1.748889
# 369        0.800000
# 370        6.775000
#
# [371 rows x 3 columns]

# %% [markdown]
# ## Comparison Score

# %%
# Create an empty DataFrame to store the results
results_df = pd.DataFrame(columns=['Activity_1', 'Activity_2', 'Comparison'])

# Comparative Analysis: This compares the mean paid-up capital of all business activities.
# It helps in understanding their relative performance and market standing.
for i in range(len(grouped_df) - 1):
    for j in range(i + 1, len(grouped_df)):
        activity1_capital = grouped_df.loc[i, 'PAIDUP_CAPITAL']
        activity2_capital = grouped_df.loc[j, 'PAIDUP_CAPITAL']
        comparison = activity1_capital / activity2_capital
        new_row = pd.DataFrame({'Activity_1': [grouped_df.loc[i, 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN']],
                                'Activity_2': [grouped_df.loc[j, 'PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN']],
                                'Comparison': [comparison]})
        results_df = pd.concat([results_df, new_row], ignore_index=True)

# Print the results DataFrame
results_df
# Out:
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
# C:\Users\kings\AppData\Local\Temp\ipykernel_15076\2416937234.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   comparison = activity1_capital / activity2_capital
#                                             Activity_1  \
# 0    Agriculture, hunting and related service activ...
# 1    Agriculture, hunting and related service activ...
# 2    Agriculture, hunting and related service activ...
# 3    Agriculture, hunting and related service activ...
# 4    Agriculture, hunting and related service activ...
# ..                                                 ...
# 815  Retail trade, except of motor vehicles and mot...
# 816  Retail trade, except of motor vehicles and mot...
# 817              Transport, storage and communications
# 818              Transport, storage and communications
# 819  Wholesale and retail trade ; repair of motor v...
#
#                                             Activity_2  Comparison
# 0                      Computer and related activities    4.368428
# 1                                         Construction    0.804129
# 2                                            Education    3.174258
# 3         Electricity, gas, steam and hot water supply    0.015313
# 4    Extraction of crude petroleum and natural gas;...    0.542147
# ..                                                 ...         ...
# 815  Wholesale and retail trade ; repair of motor v...    0.031384
# 816  Wholesale trade and commission trade, except o...    0.051639
# 817  Wholesale and retail trade ; repair of motor v...    0.396216
# 818  Wholesale trade and commission trade, except o...    0.651926
# 819  Wholesale trade and commission trade, except o...    1.645382
#
# [820 rows x 3 columns]

# %% [markdown]
# ## Liquidity Ratios

# %%
df = df.copy()

# Calculate the liquidity ratio without warnings
df.loc[:, 'LIQUIDITY_RATIO'] = df['AUTHORIZED_CAP'] / df['PAIDUP_CAPITAL']

# Now, let's create a smaller DataFrame to showcase the liquidity ratios
# Selecting relevant columns for the smaller DataFrame
liquidity_df = df[['Company_Name', 'AUTHORIZED_CAP', 'PAIDUP_CAPITAL', 'LIQUIDITY_RATIO']].copy()

# Displaying the smaller DataFrame
print("Smaller DataFrame showcasing Liquidity Ratios:")
liquidity_df
# Out:
# Smaller DataFrame showcasing Liquidity Ratios:
#                                            Company_Name  AUTHORIZED_CAP  \
# 186                    MANIPUR SPINNING MILLS CORPN LTD      20000000.0
# 493           MANIPUR BAKERY OWNERS ASSOCIATION PVT LTD         75000.0
# 918      ALL MANIPUR SMALL SCALE INDUSTRIES ASSOCIATION             0.0
# 826    PHOUOIBI SAVING CHIT & INVESTMENT CO PVT LIMITED        100000.0
# 273   MANIPUR HANDLOOM & HANDICRAFTSDEVELOPMENT CORP...       4000000.0
# ...                                                 ...             ...
# 1278            M.S.& ALLOY ELECTRODES PRIVATE LIMITED.             0.0
# 1272               GOODTESE INDUSTRIES PRIVATE LIMITED.             0.0
# 1299                               INDDABRATOR LIMITED.             0.0
# 1222             ALL MANIPUR INDUSTRIALISTS ASSOCIATION             0.0
# 1129      MANIPUR INDUSTRIAL DEVELOPMENTCORPORATION LTD       1000000.0
#
#       PAIDUP_CAPITAL  LIQUIDITY_RATIO
# 186       20000000.0         1.000000
# 493          49000.0         1.530612
# 918              0.0              NaN
# 826          10000.0        10.000000
# 273        4000000.0         1.000000
# ...              ...              ...
# 1278             0.0              NaN
# 1272             0.0              NaN
# 1299             0.0              NaN
# 1222             0.0              NaN
# 1129        200000.0         5.000000
#
# [1300 rows x 4 columns]

# %% [markdown]
# # Model

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'df' is your DataFrame
# Convert 'Latest_Year_AR' to datetime format
df['Latest_Year_AR'] = pd.to_datetime(df['Latest_Year_AR'], errors='coerce')

# Define the top 5 categories for forecasting
top_categories = [
    'Other business activities',
    'Agriculture, hunting and related service activities',
    'Construction',
    'Wholesale trade and commission trade, except of motor vehicles and motorcycles',
    'Financial intermediation'
]

# Loop through each category for forecasting
for category_to_forecast in top_categories:
    # Filter data for the specific category and the specified time range
    category_df = df[(df['PRINCIPAL_BUSINESS_ACTIVITY_AS_PER_CIN'] == category_to_forecast) & 
                     (df['Registration_Year'] >= 2013) & (df['Registration_Year'] <= 2020)]

    # Extract relevant features and target variable
    X = category_df[['Registration_Year']]
    y = category_df.groupby('Registration_Year').size()

    # Convert 'Registration_Year' to DateTime format
    y.index = pd.to_datetime(y.index, format='%Y')

    # Fit ARIMA model
    model = ARIMA(y, order=(1, 1, 1))  # Adjust order as needed
    fit_model = model.fit()

    # Forecast registrations for the next 5 years (2021-2025)
    forecast_steps = 5
    forecast_values = fit_model.forecast(steps=forecast_steps)

    # Plot the forecast
    plt.figure(figsize=(16, 6))
    plt.plot(y.index.year, y.values, marker='o', label='Historical Data')
    plt.plot(range(y.index.year.max() + 1, y.index.year.max() + 1 + forecast_steps), forecast_values, marker='o', label='Forecast')
    plt.title(f'Forecast of {category_to_forecast} registrations (2021-2025)')
    plt.xticks(np.arange(2013, 2026, 1))
    plt.xlabel('Year')
    plt.ylabel('Count of Registrations')
    plt.legend()
    plt.show()

    # Display the forecasted values
    print(f"Forecasted registrations for {category_to_forecast} for 2021-2025:")
    print(forecast_values)
# Out:
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Other business activities for 2021-2025:
# 2021-01-01    29.909982
# 2022-01-01    28.310682
# 2023-01-01    28.831613
# 2024-01-01    28.661933
# 2025-01-01    28.717202
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# Forecasted registrations for Agriculture, hunting and related service activities for 2021-2025:
# 2021-01-01    43.822583
# 2022-01-01    51.906589
# 2023-01-01    57.944994
# 2024-01-01    62.455423
# 2025-01-01    65.824521
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Construction for 2021-2025:
# 2021-01-01    18.902790
# 2022-01-01    13.116573
# 2023-01-01    18.788519
# 2024-01-01    13.228588
# 2025-01-01    18.678717
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency AS-JAN will be used.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Forecasted registrations for Wholesale trade and commission trade, except of motor vehicles and motorcycles for 2021-2025:
# 2021-01-01    17.108208
# 2022-01-01    17.908875
# 2023-01-01    18.487346
# 2024-01-01    18.905284
# 2025-01-01    19.207239
# Freq: AS-JAN, Name: predicted_mean, dtype: float64
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\kings\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Forecasted registrations for Financial intermediation for 2021-2025:
# 7     24.805516
# 8     25.577463
# 9     25.305918
# 10    25.401438
# 11    25.367837
# Name: predicted_mean, dtype: float64
